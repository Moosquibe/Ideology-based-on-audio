# %% [markdown]
# # Connecting speakers, ideology and phonetics
#
# We form our working phonetics-based dataset.

# %%
formants=open("gathered_data/wordssyllablesformants.txt",'r')
list_formants=formants.readlines()

# %% [markdown]
# - **Data cleaning.** First, we reformat the data produced by the gathering scripts.
# We form a dictionary whose keys are tuples (speaker, word, vowel, position_in_the_word) and values are the phonetics data, namely a list $[\text{frequence 1}, \text{frequence 2}, \text{duration}, \text{formant1}, \text{formant 2}]$ where both formant1 and formant2 are themselves lists containing 3 frequences.
# The script also populates a list of all the speakers.

# %%
def reformat(l,vowels_dict,names_list):
    l=l.replace('[','')
    l=l.replace(']','')
    l=l.replace("'",'')
    l=l.replace(' ','')
    l=l.split(',')
    word=l[0]
    speaker=l[1].lower()
    for i in range(3,len(l),13):
        position = ((i-3)/13)+1
        sublist=l[i:i+12]
        vowel=sublist[0]
        freq1=float(sublist[1])
        freq2=float(sublist[2])
        duration=float(sublist[3])
        formant1=[float(i) for i in sublist[4:7]]
        formant2=[float(i) for i in sublist[8:11]]
        if (speaker,word,vowel,position) in vowels_dict:
            v=vowels_dict[(speaker,word,vowel,position)]
            v[0]+=1
            v[1]+=freq1
            v[2]+=freq2
            v[3]+=duration
            for i in range(len(formant1)):
                v[4][i]+=formant1[i]
                v[5][i]+=formant2[i]

        else:
            vowels_dict[(speaker,word,vowel,position)]=[1,freq1,freq2,duration,formant1,formant2]    
    names_list.append(speaker)
    
vowels_dict={}
names_list=[]
for line in list_formants:
    reformat(line,vowels_dict,names_list)

names_list=list(set(names_list)) #in order to remove duplicates
len(names_list)
# Out:
# 804

# %% [markdown]
# - **Averaging the formants.** This is an important step.
# We average the phonetics data for each key of our dictionary. This in order the future data analysis to overestimate the role of certain "dominant" speakers in the ideology prediction. As a result, we still have a dictionary whose keys are (speaker, word, vowel), but the value is now a single, averaged phonetics information.

# %%
for e in vowels_dict:
    v=vowels_dict[e]
    count=v[0]
    v[1]=v[1]/count
    v[2]=v[2]/count
    v[3]=v[3]/count
    formant1=v[4]
    for i in range(len(formant1)):
        v[4][i]=v[4][i]/count
        v[5][i]=v[5][i]/count

# %% [markdown]
# - **Getting the ideology for each speaker.**
# However, not all the speakers appear in ideodefined.txt as the donations record for some speakers either weren't found or don't allow to conclude regarding their political orientation.
# We form a dictionary where keys are (first, last name) and values are the ideology. We find 433 different speakers with ideology.

# %%
ideology=open("gathered_data/ideodefined.txt",'r')  #file containing speakers and their respective ideology. 
list_ideology=ideology.readlines()
ideology_dict={}
names=[]
for e in list_ideology:
    l=e[:-1].split(',')
    first_name=l[0]
    last_name=l[1]
    ideo=l[2]
    ideology_dict[(first_name,last_name)]=ideo
    names.append((first_name,last_name))

# %% [markdown]
# We also create a dictionary to match names (as they do not have the same format in both files)

# %%
wordsyllablesformant_names=list(set(names_list[:]))
ideology_names=list(set(names[:]))
match={}
for m in ideology_names:
    for n in wordsyllablesformant_names:
        if (m[0] in n and m[1].replace("'",'') in n):  #replace the ' by a blank for Irish names
            wordsyllablesformant_names.remove(n)
            match[n]=m

# %% [markdown]
# - **Adding ideology to the names in the phonetics dataset**

# %%
vowels_ideology={}
keys=[]
for e in vowels_dict:
    keys.append(e)
for k in keys:
    speaker=k[0]
    word=k[1]
    vowel=k[2]
    position=k[3]
    v=vowels_dict[k]
    try:
        sep_name=match[speaker]
        ideology_of_speaker=ideology_dict[sep_name]
        vowels_ideology[(speaker,ideology_of_speaker,word,vowel,position)]=v
    except KeyError:
        oops=1

# %% [markdown]
# We do some more data formatting so that the values in the dictionary are as follows

# %%
col=['formant1','formant2','duration']

# %%
vowels_final={}
for e in vowels_ideology:
    (name,ideo,a,b,c) = e
    if float(ideo) < 0.5:
        ideo = 0
    else:
        ideo = 1
    l=[]
    v=vowels_ideology[e]
    l=v[1:4]
    vowels_final[(name,ideo,a,b)]=l

vowels_final
# Out:
# {('johnpaulstevens', 0, 'REMEDIES', 'EH'): [797.5454545454545,
#   1474.6363636363637,
#   0.049363636363636366],
#  ('johnpaulstevens', 0, 'REMEDIES', 'AH'): [623.7272727272727,
#   1571.090909090909,
#   0.03936363636363637],
#  ('johnpaulstevens', 0, 'REMEDIES', 'IY'): [489.6, 2266.1, 0.0992],
#  ('johnpaulstevens', 0, 'FLORIDA', 'AO'): [700.8461538461538,
#   903.6153846153846,
#   0.09703846153846156],
#  ('johnpaulstevens', 0, 'FLORIDA', 'AH'): [656.5769230769231,
#   1648.1538461538462,
#   0.04192307692307694],
#  ('johnpaulstevens', 0, 'PATENT', 'AE'): [936.9767441860465,
#   1869.2325581395348,
#   0.1261860465116279],
#  ('johnpaulstevens', 0, 'PATENT', 'AH'): [624.4418604651163,
#   1720.6976744186047,
#   0.031069767441860473],
#  ('johnpaulstevens', 0, 'INFRINGEMENT', 'IH'): [628.8235294117648,
#   1820.235294117647,
#   0.04170588235294118],
#  ('johnpaulstevens', 0, 'INFRINGEMENT', 'AH'): [628.125,
#   1521.125,
#   0.04025000000000001],
#  ('johnpaulstevens', 0, 'ANSWER', 'AE'): [705.984,
#   2186.848,
#   0.11851999999999999],
#  ('johnpaulstevens', 0, 'ANSWER', 'ER'): [584.144,
#   1759.568,
#   0.06380800000000002],
#  ('johnpaulstevens', 0, 'QUESTION', 'EH'): [808.0, 1625.0, 0.071],
#  ('johnpaulstevens', 0, 'QUESTION', 'AH'): [582.0, 1666.0, 0.029],
#  ('johnpaulstevens', 0, 'REMEDY', 'EH'): [781.8679245283018,
#   1476.698113207547,
#   0.05162264150943396],
#  ('johnpaulstevens', 0, 'REMEDY', 'AH'): [597.3962264150944,
#   1587.9622641509434,
#   0.03281132075471699],
#  ('johnpaulstevens', 0, 'REMEDY', 'IY'): [534.8269230769231,
#   2326.153846153846,
#   0.10903846153846151],
#  ('johnpaulstevens', 0, 'SAYING', 'EY'): [714.4964028776978,
#   1960.7985611510792,
#   0.0853165467625899],
#  ('johnpaulstevens', 0, 'SAYING', 'IH'): [629.9352517985611,
#   2213.136690647482,
#   0.03975539568345324],
#  ('johnpaulstevens', 0, 'INVERSE', 'IH'): [560.0, 2100.0, 0.07],
#  ('johnpaulstevens', 0, 'INVERSE', 'ER'): [560.0, 1363.0, 0.09],
#  ('johnpaulstevens', 0, 'CONDEMNATION', 'AA'): [835.0, 1536.0, 0.1],
#  ('johnpaulstevens', 0, 'CONDEMNATION', 'AH'): [508.0, 1853.0, 0.03],
#  ('johnpaulstevens', 0, 'CONDEMNATION', 'EY'): [626.0, 2140.0, 0.08],
#  ('johnpaulstevens', 0, 'TAKEN', 'EY'): [646.88, 2063.88, 0.09964000000000002],
#  ('johnpaulstevens', 0, 'TAKEN', 'AH'): [587.24, 1917.8, 0.03528000000000001],
#  ('johnpaulstevens', 0, 'HISTORY', 'IH'): [581.5588235294117,
#   1911.264705882353,
#   0.05079411764705883],
#  ('johnpaulstevens', 0, 'HISTORY', 'IY'): [573.625, 2198.125, 0.0875],
#  ('johnpaulstevens', 0, 'EVER', 'EH'): [683.1578947368421,
#   1947.6842105263158,
#   0.08261403508771932],
#  ('johnpaulstevens', 0, 'EVER', 'ER'): [562.3508771929825,
#   1253.3859649122808,
#   0.09940350877192984],
#  ('johnpaulstevens', 0, 'JUDGMENT', 'AH'): [622.1594202898551,
#   1512.9420289855072,
#   0.032739130434782604],
#  ('johnpaulstevens', 0, 'GRANTING', 'AE'): [697.0,
#   1913.0,
#   0.09000000000000001],
#  ('johnpaulstevens', 0, 'GRANTING', 'IH'): [573.6666666666666,
#   2137.0,
#   0.04633333333333334],
#  ('johnpaulstevens', 0, 'RELIEF', 'IY'): [517.8888888888889,
#   2251.5185185185187,
#   0.08307407407407409],
#  ('johnpaulstevens', 0, 'INTENT', 'IH'): [589.5106382978723,
#   1920.0,
#   0.04597872340425531],
#  ('johnpaulstevens', 0, 'INTENT', 'EH'): [709.936170212766,
#   2029.0425531914893,
#   0.11682978723404261],
#  ('johnpaulstevens', 0, 'ELEMENT', 'EH'): [770.1818181818181,
#   1666.8181818181818,
#   0.05727272727272728],
#  ('johnpaulstevens', 0, 'ELEMENT', 'AH'): [630.2727272727273,
#   1175.6363636363637,
#   0.03363636363636364],
#  ('johnpaulstevens', 0, 'SUGGESTING', 'AH'): [553.551724137931,
#   2068.206896551724,
#   0.03693103448275863],
#  ('johnpaulstevens', 0, 'SUGGESTING', 'EH'): [748.7586206896551,
#   1795.7241379310344,
#   0.058137931034482775],
#  ('johnpaulstevens', 0, 'SUGGESTING', 'IH'): [611.6896551724138,
#   2013.5172413793102,
#   0.04300000000000002],
#  ('johnpaulstevens', 0, 'TAKINGS', 'EY'): [579.0, 2265.0, 0.131],
#  ('johnpaulstevens', 0, 'TAKINGS', 'IH'): [509.0, 1783.0, 0.04],
#  ('johnpaulstevens', 0, 'COEXTENSIVE', 'OW'): [656.5, 1046.5, 0.14],
#  ('johnpaulstevens', 0, 'COEXTENSIVE', 'IH'): [536.0, 1682.0, 0.06],
#  ('johnpaulstevens', 0, 'COEXTENSIVE', 'EH'): [705.5, 1986.5, 0.095],
#  ('johnpaulstevens', 0, 'SEPARATE', 'EH'): [807.695652173913,
#   1743.8695652173913,
#   0.06873913043478262],
#  ('johnpaulstevens', 0, 'SEPARATE', 'AH'): [595.5,
#   1625.5,
#   0.03833333333333334],
#  ('johnpaulstevens', 0, 'ISSUE', 'IH'): [484.0, 2136.0, 0.111],
#  ('johnpaulstevens', 0, 'ISSUE', 'UW'): [519.0, 1773.0, 0.08],
#  ('johnpaulstevens', 0, 'INFRINGEMENTS', 'IH'): [602.0, 1826.0, 0.04],
#  ('johnpaulstevens', 0, 'INFRINGEMENTS', 'AH'): [501.0, 1380.0, 0.03],
#  ('johnpaulstevens', 0, 'PRIVATE', 'AY'): [965.9, 1381.1, 0.1169],
#  ('johnpaulstevens', 0, 'PRIVATE', 'AH'): [591.6,
#   1671.7,
#   0.036000000000000004],
#  ('johnpaulstevens', 0, 'PARTIES', 'AA'): [830.0, 1169.0, 0.08164000000000002],
#  ('johnpaulstevens', 0, 'PARTIES', 'IY'): [531.32,
#   2216.18,
#   0.07740000000000001],
#  ('johnpaulstevens', 0, 'IN', 'AH'): [602.1578947368421,
#   1784.7894736842106,
#   0.04521052631578948],
#  ('johnpaulstevens', 0, 'IN', 'IH'): [620.5, 2219.0, 0.11025000000000001],
#  ('johnpaulstevens', 0, 'ECONOMY', 'IH'): [561.0, 2253.0, 0.04],
#  ('johnpaulstevens', 0, 'ECONOMY', 'AA'): [945.0, 1659.0, 0.1],
#  ('johnpaulstevens', 0, 'ECONOMY', 'AH'): [770.0, 1572.0, 0.03],
#  ('johnpaulstevens', 0, 'ECONOMY', 'IY'): [536.0, 2292.0, 0.09],
#  ('johnpaulstevens', 0, 'PLAYERS', 'EY'): [604.5, 1944.5, 0.04],
#  ('johnpaulstevens', 0, 'PLAYERS', 'ER'): [551.5, 1525.0, 0.15050000000000002],
#  ('johnpaulstevens', 0, 'ISNT', 'AH'): [573.6333333333333,
#   1640.75,
#   0.035488888888888896],
#  ('johnpaulstevens', 0, 'CHANGING', 'EY'): [611.4545454545455,
#   2308.818181818182,
#   0.117],
#  ('johnpaulstevens', 0, 'CHANGING', 'AH'): [546.3636363636364,
#   2458.909090909091,
#   0.032818181818181816],
#  ('johnpaulstevens', 0, 'VERY', 'EH'): [624.0, 1255.0, 0.031],
#  ('johnpaulstevens', 0, 'VERY', 'IY'): [591.0, 2082.0, 0.06],
#  ('johnpaulstevens', 0, 'RAPIDLY', 'AE'): [979.0, 1779.5, 0.1255],
#  ('johnpaulstevens', 0, 'RAPIDLY', 'AH'): [608.5, 1502.5, 0.0405],
#  ('johnpaulstevens', 0, 'RAPIDLY', 'IY'): [520.5, 2138.5, 0.085],
#  ('johnpaulstevens', 0, 'WANTED', 'AO'): [856.7027027027027,
#   1107.3783783783783,
#   0.06827027027027026],
#  ('johnpaulstevens', 0, 'WANTED', 'AH'): [592.7837837837837,
#   1660.7027027027027,
#   0.045945945945945955],
#  ('johnpaulstevens', 0, 'AMICUS', 'AH'): [578.2727272727273,
#   1916.7272727272727,
#   0.04454545454545455],
#  ('johnpaulstevens', 0, 'AMICUS', 'IY'): [569.2, 1808.6, 0.0416],
#  ('johnpaulstevens', 0, 'HUNDRED', 'AH'): [535.0, 1865.0, 0.04],
#  ('johnpaulstevens', 0, 'HUNDRED', 'ER'): [555.75, 1601.575, 0.087225],
#  ('johnpaulstevens', 0, 'PATENTS', 'AE'): [761.0,
#   2116.714285714286,
#   0.15257142857142858],
#  ('johnpaulstevens', 0, 'PATENTS', 'AH'): [507.42857142857144,
#   1807.0,
#   0.029857142857142856],
#  ('johnpaulstevens', 0, 'ASSUME', 'AH'): [493.0, 1855.0, 0.08],
#  ('johnpaulstevens', 0, 'ASSUME', 'UW'): [593.0, 1389.0, 0.06],
#  ('johnpaulstevens', 0, 'FAIRLY', 'EH'): [627.8846153846154,
#   1701.6538461538462,
#   0.05307692307692309],
#  ('johnpaulstevens', 0, 'FAIRLY', 'IY'): [553.0,
#   2072.423076923077,
#   0.08065384615384616],
#  ('johnpaulstevens', 0, 'RECENT', 'IY'): [495.875, 2352.75, 0.061375],
#  ('johnpaulstevens', 0, 'RECENT', 'AH'): [619.0, 1661.25, 0.04375],
#  ('johnpaulstevens', 0, 'DEVELOPMENT', 'IH'): [650.3333333333334,
#   1585.3333333333333,
#   0.03666666666666667],
#  ('johnpaulstevens', 0, 'DEVELOPMENT', 'EH'): [760.0,
#   1343.6666666666667,
#   0.13],
#  ('johnpaulstevens', 0, 'DEVELOPMENT', 'AH'): [658.0,
#   1386.0,
#   0.03333333333333333],
#  ('johnpaulstevens', 0, 'MAYBE', 'EY'): [660.7464788732394,
#   2049.478873239437,
#   0.09315492957746477],
#  ('johnpaulstevens', 0, 'MAYBE', 'IY'): [500.3521126760563,
#   2257.4647887323945,
#   0.06926760563380281],
#  ('johnpaulstevens', 0, 'BECAME', 'IH'): [597.4, 2033.0, 0.036000000000000004],
#  ('johnpaulstevens', 0, 'BECAME', 'EY'): [615.625,
#   2341.125,
#   0.07150000000000001],
#  ('johnpaulstevens', 0, 'OVER', 'OW'): [644.9156626506024,
#   978.6385542168674,
#   0.11489156626506025],
#  ('johnpaulstevens', 0, 'OVER', 'ER'): [567.855421686747,
#   1219.7590361445782,
#   0.07901204819277106],
#  ('johnpaulstevens', 0, 'COUNTRY', 'AH'): [836.1071428571429,
#   1556.107142857143,
#   0.06850000000000002],
#  ('johnpaulstevens', 0, 'COUNTRY', 'IY'): [528.6071428571429,
#   2185.285714285714,
#   0.08196428571428571],
#  ('johnpaulstevens', 0, 'ENGAGING', 'EH'): [666.6, 2034.6, 0.0578],
#  ('johnpaulstevens', 0, 'ENGAGING', 'EY'): [584.5, 2445.25, 0.12225],
#  ('johnpaulstevens', 0, 'ENGAGING', 'IH'): [542.0, 1992.0, 0.03],
#  ('johnpaulstevens', 0, 'INTELLECTUAL', 'IH'): [563.5,
#   1930.5,
#   0.060000000000000005],
#  ('johnpaulstevens', 0, 'INTELLECTUAL', 'AH'): [615.0, 827.5, 0.03],
#  ('johnpaulstevens', 0, 'INTELLECTUAL', 'EH'): [845.5, 1535.5, 0.06],
#  ('johnpaulstevens', 0, 'INTELLECTUAL', 'UW'): [813.5, 1316.0, 0.0655],
#  ('johnpaulstevens', 0, 'ACTIVITY', 'AE'): [802.8461538461538,
#   1933.1538461538462,
#   0.09607692307692307],
#  ('johnpaulstevens', 0, 'ACTIVITY', 'IH'): [571.7692307692307,
#   1964.076923076923,
#   0.06538461538461539],
#  ('johnpaulstevens', 0, 'ACTIVITY', 'AH'): [524.6153846153846,
#   1657.0,
#   0.036846153846153855],
#  ('johnpaulstevens', 0, 'ACTIVITY', 'IY'): [516.5384615384615,
#   2278.923076923077,
#   0.09999999999999999],
#  ('johnpaulstevens', 0, 'SITUATIONS', 'IH'): [575.5454545454545,
#   1950.1818181818182,
#   0.04554545454545455],
#  ('johnpaulstevens', 0, 'SITUATIONS', 'UW'): [529.4545454545455,
#   915.0909090909091,
#   0.13827272727272727],
#  ('johnpaulstevens', 0, 'SITUATIONS', 'EY'): [617.2727272727273,
#   1948.1818181818182,
#   0.05281818181818183],
#  ('johnpaulstevens', 0, 'SITUATIONS', 'AH'): [688.2727272727273,
#   1906.0,
#   0.0300909090909091],
#  ('johnpaulstevens', 0, 'POSSIBLY', 'AA'): [1060.75, 1208.5, 0.112375],
#  ('johnpaulstevens', 0, 'POSSIBLY', 'AH'): [588.875,
#   1258.625,
#   0.037500000000000006],
#  ('johnpaulstevens', 0, 'POSSIBLY', 'IY'): [497.57142857142856,
#   2171.285714285714,
#   0.08457142857142856],
#  ('johnpaulstevens', 0, 'ENGAGE', 'EH'): [603.0, 1896.25, 0.04],
#  ('johnpaulstevens', 0, 'ENGAGE', 'EY'): [571.0, 2383.0, 0.1675],
#  ('johnpaulstevens', 0, 'ACTIVITIES', 'AE'): [743.0, 1849.0, 0.16],
#  ('johnpaulstevens', 0, 'ACTIVITIES', 'IH'): [534.0, 1814.0, 0.079],
#  ('johnpaulstevens', 0, 'ACTIVITIES', 'AH'): [546.0, 1507.0, 0.03],
#  ('johnpaulstevens', 0, 'ACTIVITIES', 'IY'): [478.0, 2345.0, 0.1],
#  ('johnpaulstevens', 0, 'INFRINGE', 'IH'): [577.5, 1994.0, 0.0495],
#  ('johnpaulstevens', 0, 'WHETHER', 'EH'): [690.6454849498327,
#   1296.1571906354516,
#   0.04132107023411364],
#  ('johnpaulstevens', 0, 'WHETHER', 'ER'): [580.9397993311037,
#   1572.4816053511706,
#   0.06670568561872903],
#  ('johnpaulstevens', 0, 'GOING', 'OW'): [643.2840909090909,
#   1469.8522727272727,
#   0.05639772727272725],
#  ('johnpaulstevens', 0, 'GOING', 'IH'): [645.8709677419355,
#   1682.741935483871,
#   0.05664516129032259],
#  ('johnpaulstevens', 0, 'AREA', 'EH'): [629.25,
#   1978.2916666666667,
#   0.09550000000000002],
#  ('johnpaulstevens', 0, 'AREA', 'IY'): [541.1666666666666,
#   2113.3333333333335,
#   0.09566666666666668],
#  ('johnpaulstevens', 0, 'AREA', 'AH'): [628.875, 1895.5, 0.04300000000000002],
#  ('johnpaulstevens', 0, 'ANY', 'EH'): [583.0, 2396.0, 0.09],
#  ('johnpaulstevens', 0, 'ANY', 'IY'): [503.0, 2734.0, 0.13],
#  ('johnpaulstevens', 0, 'ENTITY', 'EH'): [679.1428571428571,
#   1926.5714285714287,
#   0.08671428571428572],
#  ('johnpaulstevens', 0, 'ENTITY', 'AH'): [590.7142857142857,
#   1703.0,
#   0.05585714285714286],
#  ('johnpaulstevens', 0, 'ENTITY', 'IY'): [503.85714285714283,
#   2292.8571428571427,
#   0.1142857142857143],
#  ('johnpaulstevens', 0, 'BUSINESS', 'IH'): [586.8870967741935,
#   1733.1129032258063,
#   0.057467741935483874],
#  ('johnpaulstevens', 0, 'BUSINESS', 'AH'): [588.6129032258065,
#   1520.2903225806451,
#   0.04962903225806451],
#  ('johnpaulstevens', 0, 'INVOLVED', 'IH'): [591.7037037037037,
#   1685.1851851851852,
#   0.04674074074074074],
#  ('johnpaulstevens', 0, 'INVOLVED', 'AA'): [941.9629629629629,
#   1065.1851851851852,
#   0.17303703703703702],
#  ('johnpaulstevens', 0, 'ARGUMENTS', 'AA'): [853.5333333333333,
#   1553.6666666666667,
#   0.07479999999999999],
#  ('johnpaulstevens', 0, 'ARGUMENTS', 'AH'): [613.6,
#   1586.9333333333334,
#   0.029933333333333347],
#  ('johnpaulstevens', 0, 'ABOUT', 'AH'): [608.25, 1232.0, 0.08975],
#  ('johnpaulstevens', 0, 'ABOUT', 'AW'): [836.25, 1242.5, 0.19000000000000003],
#  ('johnpaulstevens', 0, 'INVENTION', 'IH'): [577.6,
#   1875.4,
#   0.046400000000000004],
#  ('johnpaulstevens', 0, 'INVENTION', 'EH'): [680.6, 1799.0, 0.06],
#  ('johnpaulstevens', 0, 'INVENTION', 'AH'): [648.8,
#   1709.8,
#   0.054200000000000005],
#  ('johnpaulstevens', 0, 'ALSO', 'AO'): [858.7611940298508,
#   1009.9328358208955,
#   0.13058955223880597],
#  ('johnpaulstevens', 0, 'ALSO', 'OW'): [805.044776119403,
#   1407.9850746268658,
#   0.1259029850746268],
#  ('johnpaulstevens', 0, 'QUESTIONS', 'EH'): [799.9130434782609,
#   1541.1739130434783,
#   0.05289130434782608],
#  ('johnpaulstevens', 0, 'QUESTIONS', 'AH'): [575.804347826087,
#   1776.4130434782608,
#   0.03600000000000001],
#  ('johnpaulstevens', 0, 'ARISING', 'ER'): [538.5, 987.0, 0.165],
#  ('johnpaulstevens', 0, 'ARISING', 'AY'): [957.5, 1412.5, 0.11449999999999999],
#  ('johnpaulstevens', 0, 'ARISING', 'IH'): [599.0, 2121.5, 0.0345],
#  ('johnpaulstevens', 0, 'NECESSARILY', 'EH'): [656.4074074074074,
#   1730.6666666666667,
#   0.06962962962962964],
#  ('johnpaulstevens', 0, 'NECESSARILY', 'AH'): [668.8518518518518,
#   1272.2962962962963,
#   0.03292592592592594],
#  ('johnpaulstevens', 0, 'NECESSARILY', 'IY'): [561.1923076923077,
#   2012.5,
#   0.0719615384615385],
#  ('johnpaulstevens', 0, 'DELIBERATELY', 'AH'): [624.75, 1517.75, 0.0325],
#  ('johnpaulstevens', 0, 'DELIBERATELY', 'IH'): [587.0, 1637.0, 0.04],
#  ('johnpaulstevens', 0, 'DELIBERATELY', 'IY'): [502.6666666666667,
#   2224.0,
#   0.084],
#  ('johnpaulstevens', 0, 'ACTIVE', 'AE'): [776.5,
#   2109.1666666666665,
#   0.11499999999999999],
#  ('johnpaulstevens', 0, 'ACTIVE', 'IH'): [562.3333333333334,
#   2040.6666666666667,
#   0.05666666666666667],
#  ('johnpaulstevens', 0, 'PARTICIPANT', 'AA'): [801.5,
#   1252.8333333333333,
#   0.042],
#  ('johnpaulstevens', 0, 'PARTICIPANT', 'IH'): [578.5,
#   1864.5,
#   0.049999999999999996],
#  ('johnpaulstevens', 0, 'PARTICIPANT', 'AH'): [647.6666666666666,
#   1554.0,
#   0.036833333333333336],
#  ('johnpaulstevens', 0, 'MARKETPLACE', 'AA'): [827.5,
#   1207.5,
#   0.07500000000000001],
#  ('johnpaulstevens', 0, 'MARKETPLACE', 'AH'): [573.0, 1872.0, 0.0405],
#  ('johnpaulstevens', 0, 'MARKETPLACE', 'EY'): [620.5, 1906.5, 0.0755],
#  ('johnpaulstevens', 0, 'PROBLEMS', 'AA'): [972.4615384615385,
#   1156.1538461538462,
#   0.10684615384615384],
#  ('johnpaulstevens', 0, 'PROBLEMS', 'AH'): [600.6153846153846,
#   1136.3846153846155,
#   0.03157692307692309],
#  ('johnpaulstevens', 0, 'ARISE', 'ER'): [573.2307692307693,
#   1064.3846153846155,
#   0.1586153846153846],
#  ('johnpaulstevens', 0, 'ARISE', 'AY'): [1018.0,
#   1412.2307692307693,
#   0.2161538461538461],
#  ('johnpaulstevens', 0, 'QUITE', 'AY'): [880.0, 913.0, 0.119],
#  ('johnpaulstevens', 0, 'ABSENCE', 'AE'): [721.8, 2079.2, 0.158],
#  ('johnpaulstevens', 0, 'ABSENCE', 'AH'): [584.6, 1514.2, 0.0354],
#  ('johnpaulstevens', 0, 'LITIGATION', 'IH'): [592.2941176470588,
#   1479.6764705882354,
#   0.03594117647058825],
#  ('johnpaulstevens', 0, 'LITIGATION', 'AH'): [566.0, 1967.5, 0.0345],
#  ('johnpaulstevens', 0, 'LITIGATION', 'EY'): [604.03125,
#   2316.96875,
#   0.1151875],
#  ('johnpaulstevens', 0, 'PROBLEM', 'AA'): [1054.0, 1222.0, 0.13],
#  ('johnpaulstevens', 0, 'PROBLEM', 'AH'): [593.0, 1190.0, 0.03],
#  ('johnpaulstevens', 0, 'BECAUSE', 'IH'): [598.8482972136223,
#   1940.325077399381,
#   0.045687306501547974],
#  ('johnpaulstevens', 0, 'BECAUSE', 'AH'): [660.5492063492063,
#   1729.3555555555556,
#   0.05324761904761899],
#  ('johnpaulstevens', 0, 'BASICALLY', 'EY'): [654.5882352941177,
#   2100.6470588235293,
#   0.10594117647058825],
#  ('johnpaulstevens', 0, 'BASICALLY', 'IH'): [515.9411764705883,
#   2114.235294117647,
#   0.04947058823529413],
#  ('johnpaulstevens', 0, 'BASICALLY', 'IY'): [566.8125,
#   2102.375,
#   0.07737500000000001],
#  ('johnpaulstevens', 0, 'MOTIVATE', 'OW'): [795.5, 1155.0, 0.12],
#  ('johnpaulstevens', 0, 'MOTIVATE', 'AH'): [626.0, 1224.5, 0.04],
#  ('johnpaulstevens', 0, 'MOTIVATE', 'EY'): [621.5, 1830.5, 0.129],
#  ('johnpaulstevens', 0, 'ALWAYS', 'AO'): [873.8474576271186,
#   991.8644067796611,
#   0.1291186440677966],
#  ('johnpaulstevens', 0, 'ALWAYS', 'IY'): [568.0178571428571,
#   1293.0892857142858,
#   0.03126785714285716],
#  ('johnpaulstevens', 0, 'UNTIL', 'AH'): [616.8571428571429,
#   1602.107142857143,
#   0.04496428571428573],
#  ('johnpaulstevens', 0, 'UNTIL', 'IH'): [594.25,
#   1607.75,
#   0.039107142857142875],
#  ('johnpaulstevens', 0, 'SOMEBODY', 'AH'): [617.2727272727273,
#   1521.4848484848485,
#   0.04133333333333334],
#  ('johnpaulstevens', 0, 'SOMEBODY', 'IY'): [560.5,
#   2187.090909090909,
#   0.07604545454545454],
#  ('johnpaulstevens', 0, 'INJUNCTION', 'IH'): [554.3157894736842,
#   2013.8947368421052,
#   0.04247368421052632],
#  ('johnpaulstevens', 0, 'INJUNCTION', 'AH'): [893.0, 1509.0, 0.111],
#  ('johnpaulstevens', 0, 'AGAINST', 'AH'): [571.1911764705883,
#   2041.5588235294117,
#   0.04105147058823531],
#  ('johnpaulstevens', 0, 'AGAINST', 'EH'): [636.3529411764706,
#   2225.073529411765,
#   0.07567647058823535],
#  ('johnpaulstevens', 0, 'WORRY', 'ER'): [579.0, 1013.0, 0.08],
#  ('johnpaulstevens', 0, 'WORRY', 'IY'): [533.0,
#   2245.6666666666665,
#   0.09666666666666668],
#  ('johnpaulstevens', 0, 'DAMAGE', 'AE'): [686.5, 2174.7, 0.11299999999999999],
#  ('johnpaulstevens', 0, 'DAMAGE', 'AH'): [551.1, 1833.3, 0.033],
#  ('johnpaulstevens', 0, 'LIABILITY', 'AH'): [576.3461538461538,
#   1305.423076923077,
#   0.032000000000000015],
#  ('johnpaulstevens', 0, 'LIABILITY', 'IH'): [620.8076923076923,
#   1406.923076923077,
#   0.03384615384615386],
#  ('johnpaulstevens', 0, 'LIABILITY', 'IY'): [556.0,
#   2108.6,
#   0.08751999999999999],
#  ('johnpaulstevens', 0, 'DEBATING', 'AH'): [642.5, 1579.5, 0.035],
#  ('johnpaulstevens', 0, 'DEBATING', 'EY'): [603.0, 1857.0, 0.03],
#  ('johnpaulstevens', 0, 'DEBATING', 'IH'): [545.0, 2159.0, 0.03],
#  ('johnpaulstevens', 0, 'LEGISLATIVE', 'EH'): [712.0869565217391,
#   1646.695652173913,
#   0.03891304347826088],
#  ('johnpaulstevens', 0, 'LEGISLATIVE', 'AH'): [552.0, 1747.0, 0.03],
#  ('johnpaulstevens', 0, 'LEGISLATIVE', 'EY'): [628.0, 1655.0, 0.051],
#  ('johnpaulstevens', 0, 'LEGISLATIVE', 'IH'): [599.6086956521739,
#   1900.608695652174,
#   0.04608695652173914],
#  ('johnpaulstevens', 0, 'HISTORY', 'ER'): [619.75, 1758.625, 0.036125],
#  ('johnpaulstevens', 0, 'ONLY', 'OW'): [716.8901734104046,
#   1054.9942196531792,
#   0.11546242774566477],
#  ('johnpaulstevens', 0, 'ONLY', 'IY'): [541.7919075144508,
#   2307.3699421965316,
#   0.08346242774566477],
#  ('johnpaulstevens', 0, 'CONDEMN', 'AH'): [575.0, 1666.0, 0.0295],
#  ('johnpaulstevens', 0, 'CONDEMN', 'EH'): [756.5, 1320.5, 0.035],
#  ('johnpaulstevens', 0, 'FIFTY', 'IH'): [842.0, 1306.0, 0.03],
#  ('johnpaulstevens', 0, 'FIFTY', 'IY'): [609.0, 1500.0, 0.029],
#  ('kevinjculligan', 0, 'MR', 'IH'): [561.0, 1824.0, 0.04],
#  ('kevinjculligan', 0, 'MR', 'ER'): [458.0, 1925.0, 0.05],
#  ('kevinjculligan', 0, 'JUSTICE', 'AH'): [572.0, 1612.8333333333333, 0.0415],
#  ('kevinjculligan', 0, 'CONSTITUTIONALITY', 'AA'): [927.0,
#   1382.5,
#   0.08549999999999999],
#  ('kevinjculligan', 0, 'CONSTITUTIONALITY', 'AH'): [596.0, 1540.5, 0.03],
#  ('kevinjculligan', 0, 'CONSTITUTIONALITY', 'UW'): [474.0, 1924.0, 0.04],
#  ('kevinjculligan', 0, 'CONSTITUTIONALITY', 'AE'): [897.0, 1729.0, 0.09],
#  ('kevinjculligan', 0, 'CONSTITUTIONALITY', 'IY'): [491.5, 2101.0, 0.0455],
#  ('kevinjculligan', 0, 'CONGRESS', 'AA'): [924.7142857142857,
#   1280.7857142857142,
#   0.10692857142857141],
#  ('kevinjculligan', 0, 'CONGRESS', 'AH'): [526.5, 1576.0, 0.0345],
#  ('kevinjculligan', 0, 'ENACTMENT', 'EH'): [626.6666666666666,
#   1913.3333333333333,
#   0.03966666666666666],
#  ('kevinjculligan', 0, 'ENACTMENT', 'AE'): [878.0,
#   1787.0,
#   0.12666666666666668],
#  ('kevinjculligan', 0, 'ENACTMENT', 'AH'): [626.0,
#   1688.3333333333333,
#   0.03333333333333333],
#  ('kevinjculligan', 0, 'PATENT', 'AE'): [919.4864864864865,
#   1759.5405405405406,
#   0.13564864864864867],
#  ('kevinjculligan', 0, 'PATENT', 'AH'): [585.8378378378378,
#   1768.8648648648648,
#   0.042216216216216226],
#  ('kevinjculligan', 0, 'REMEDY', 'EH'): [801.3333333333334,
#   1690.6666666666667,
#   0.06983333333333333],
#  ('kevinjculligan', 0, 'REMEDY', 'AH'): [594.0,
#   1714.8333333333333,
#   0.03866666666666667],
#  ('kevinjculligan', 0, 'REMEDY', 'IY'): [476.2, 2461.4, 0.09380000000000002],
#  ('kevinjculligan', 0, 'MEASURED', 'EH'): [814.5, 1872.5, 0.085],
#  ('kevinjculligan', 0, 'MEASURED', 'ER'): [559.5, 1794.5, 0.075],
#  ('kevinjculligan', 0, 'YARDSTICK', 'AA'): [801.0, 1007.0, 0.12],
#  ('kevinjculligan', 0, 'YARDSTICK', 'IH'): [606.0, 1865.0, 0.06],
#  ('kevinjculligan', 0, 'EMPLOYED', 'AH'): [581.0, 1382.0, 0.03],
#  ('kevinjculligan', 0, 'EMPLOYED', 'OY'): [672.0, 805.0, 0.11],
#  ('kevinjculligan', 0, 'KATZENBACH', 'AE'): [901.5, 1846.5, 0.12],
#  ('kevinjculligan', 0, 'KATZENBACH', 'AH'): [495.5, 1769.0, 0.035],
#  ('kevinjculligan', 0, 'KATZENBACH', 'AA'): [858.5, 1714.0, 0.11],
#  ('kevinjculligan', 0, 'AGAINST', 'AH'): [511.0, 2017.0, 0.0295],
#  ('kevinjculligan', 0, 'AGAINST', 'EH'): [686.5, 2243.5, 0.045],
#  ('kevinjculligan', 0, 'MORGAN', 'AO'): [690.25, 816.25, 0.08975],
#  ('kevinjculligan', 0, 'MORGAN', 'AH'): [575.75,
#   1973.75,
#   0.044750000000000005],
#  ('kevinjculligan', 0, 'CLASSIC', 'AE'): [821.0, 1791.0, 0.099],
#  ('kevinjculligan', 0, 'CLASSIC', 'IH'): [637.0, 1847.0, 0.029],
#  ('kevinjculligan', 0, 'FORMULATION', 'AO'): [639.0, 992.0, 0.06],
#  ('kevinjculligan', 0, 'FORMULATION', 'AH'): [604.0, 1775.0, 0.031],
#  ('kevinjculligan', 0, 'FORMULATION', 'EY'): [674.0, 1785.0, 0.061],
#  ('kevinjculligan', 0, 'AUTHORITY', 'AH'): [584.3333333333334,
#   1625.3333333333333,
#   0.029666666666666664],
#  ('kevinjculligan', 0, 'AUTHORITY', 'AO'): [702.6666666666666,
#   980.6666666666666,
#   0.1406666666666667],
#  ('kevinjculligan', 0, 'ARTICULATED', 'AA'): [969.0, 1738.0, 0.06],
#  ('kevinjculligan', 0, 'ARTICULATED', 'IH'): [565.0, 1954.0, 0.06],
#  ('kevinjculligan', 0, 'ARTICULATED', 'AH'): [492.0, 1876.0, 0.039],
#  ('kevinjculligan', 0, 'ARTICULATED', 'EY'): [669.0, 1673.0, 0.059],
#  ('kevinjculligan', 0, 'MARSHALL', 'AA'): [813.0, 942.0, 0.07],
#  ('kevinjculligan', 0, 'MARSHALL', 'AH'): [649.0, 1047.0, 0.04],
#  ('kevinjculligan', 0, 'MCCULLOCH', 'AH'): [655.0, 1274.0, 0.03],
#  ('kevinjculligan', 0, 'MARYLAND', 'EH'): [655.0, 1704.0, 0.09],
#  ('kevinjculligan', 0, 'MARYLAND', 'AH'): [659.0, 1806.0, 0.03],
#  ('kevinjculligan', 0, 'LEGITIMATE', 'AH'): [596.0, 1831.0, 0.04],
#  ('kevinjculligan', 0, 'WITHIN', 'IH'): [576.0, 1700.0, 0.0455],
#  ('kevinjculligan', 0, 'CONSTITUTION', 'AA'): [822.5, 1402.0, 0.09],
#  ('kevinjculligan', 0, 'CONSTITUTION', 'AH'): [583.5, 1770.5, 0.0455],
#  ('kevinjculligan', 0, 'CONSTITUTION', 'UW'): [510.5, 2040.5, 0.095],
#  ('kevinjculligan', 0, 'APPROPRIATE', 'AH'): [611.0,
#   1957.6666666666667,
#   0.06366666666666666],
#  ('kevinjculligan', 0, 'APPROPRIATE', 'OW'): [662.3333333333334,
#   1043.6666666666667,
#   0.09666666666666668],
#  ('kevinjculligan', 0, 'APPROPRIATE', 'IY'): [490.0,
#   2329.6666666666665,
#   0.06333333333333334],
#  ('kevinjculligan', 0, 'PLAINLY', 'EY'): [694.0, 1952.0, 0.03],
#  ('kevinjculligan', 0, 'PLAINLY', 'IY'): [549.0, 2582.0, 0.05],
#  ('kevinjculligan', 0, 'ADAPTED', 'AH'): [657.0, 1707.0, 0.03],
#  ('kevinjculligan', 0, 'ADAPTED', 'AE'): [815.0, 1818.0, 0.15],
#  ('kevinjculligan', 0, 'PROHIBITED', 'OW'): [550.0, 1752.0, 0.031],
#  ('kevinjculligan', 0, 'PROHIBITED', 'IH'): [606.0, 1990.0, 0.08],
#  ('kevinjculligan', 0, 'PROHIBITED', 'AH'): [580.0, 1926.0, 0.09],
#  ('kevinjculligan', 0, 'CONSISTENT', 'AH'): [480.0, 1481.0, 0.029],
#  ('kevinjculligan', 0, 'CONSISTENT', 'IH'): [611.0, 1665.0, 0.061],
#  ('kevinjculligan', 0, 'LETTER', 'EH'): [689.0, 1561.0, 0.029],
#  ('kevinjculligan', 0, 'LETTER', 'ER'): [572.0, 1556.0, 0.03],
#  ('kevinjculligan', 0, 'SPIRIT', 'IH'): [505.0, 1902.0, 0.08],
#  ('kevinjculligan', 0, 'SPIRIT', 'AH'): [506.0, 1603.0, 0.031],
#  ('kevinjculligan', 0, 'CONSTITUTIONAL', 'AA'): [948.0, 1418.5, 0.0825],
#  ('kevinjculligan', 0, 'CONSTITUTIONAL', 'AH'): [660.0, 909.75, 0.03175],
#  ('kevinjculligan', 0, 'CONSTITUTIONAL', 'UW'): [511.75,
#   2010.5,
#   0.06974999999999999],
#  ('kevinjculligan', 0, 'STATED', 'EY'): [608.0, 1921.5, 0.11549999999999999],
#  ('kevinjculligan', 0, 'STATED', 'AH'): [515.5, 1938.0, 0.04],
#  ('kevinjculligan', 0, 'SECTION', 'EH'): [720.0, 1604.0, 0.0658],
#  ('kevinjculligan', 0, 'SECTION', 'AH'): [553.2, 1684.8, 0.032],
#  ('kevinjculligan', 0, 'FOURTEENTH', 'AO'): [576.1666666666666,
#   836.1666666666666,
#   0.07666666666666667],
#  ('kevinjculligan', 0, 'FOURTEENTH', 'IY'): [530.5,
#   2543.5,
#   0.053333333333333344],
#  ('kevinjculligan', 0, 'AMENDMENT', 'AH'): [592.75,
#   1748.5,
#   0.06237500000000002],
#  ('kevinjculligan', 0, 'AMENDMENT', 'EH'): [767.75,
#   1787.875,
#   0.06987499999999999],
#  ('kevinjculligan', 0, 'CORRECTLY', 'ER'): [508.0, 900.0, 0.13],
#  ('kevinjculligan', 0, 'CORRECTLY', 'EH'): [772.0, 1806.0, 0.07],
#  ('kevinjculligan', 0, 'CORRECTLY', 'IY'): [465.0, 2303.0, 0.06],
#  ('kevinjculligan', 0, 'POSITIVE', 'AA'): [930.0, 1166.0, 0.14],
#  ('kevinjculligan', 0, 'POSITIVE', 'AH'): [543.0, 1550.0, 0.04],
#  ('kevinjculligan', 0, 'POSITIVE', 'IH'): [518.0, 1443.0, 0.03],
#  ('kevinjculligan', 0, 'LEGISLATIVE', 'AH'): [525.0, 1627.0, 0.029],
#  ('kevinjculligan', 0, 'LEGISLATIVE', 'EY'): [624.0, 1806.0, 0.029],
#  ('kevinjculligan', 0, 'LEGISLATIVE', 'IH'): [601.0, 2202.0, 0.039],
#  ('kevinjculligan', 0, 'POWER', 'AW'): [970.0,
#   1575.2222222222222,
#   0.1677777777777778],
#  ('kevinjculligan', 0, 'POWER', 'ER'): [654.8888888888889,
#   1352.888888888889,
#   0.08666666666666667],
#  ('kevinjculligan', 0, 'AUTHORIZES', 'AO'): [788.0, 810.0, 0.201],
#  ('kevinjculligan', 0, 'AUTHORIZES', 'ER'): [504.0, 1232.0, 0.09],
#  ('kevinjculligan', 0, 'AUTHORIZES', 'AH'): [613.0, 2017.0, 0.031],
#  ('kevinjculligan', 0, 'EXERCISE', 'EH'): [849.0, 2072.0, 0.109],
#  ('kevinjculligan', 0, 'EXERCISE', 'ER'): [491.0, 1683.0, 0.039],
#  ('kevinjculligan', 0, 'DISCRETION', 'IH'): [492.0, 1599.0, 0.049],
#  ('kevinjculligan', 0, 'DISCRETION', 'EH'): [721.0, 1697.0, 0.1],
#  ('kevinjculligan', 0, 'DISCRETION', 'AH'): [528.0, 1892.0, 0.051],
#  ('kevinjculligan', 0, 'DETERMINING', 'AH'): [562.0, 1697.5, 0.029],
#  ('kevinjculligan', 0, 'DETERMINING', 'ER'): [668.5, 1571.5, 0.0995],
#  ('kevinjculligan', 0, 'DETERMINING', 'IH'): [564.0, 2392.5, 0.0395],
#  ('kevinjculligan', 0, 'WHETHER', 'EH'): [715.25, 1582.5, 0.0675],
#  ('kevinjculligan', 0, 'WHETHER', 'ER'): [563.75, 1606.5, 0.11524999999999999],
#  ('kevinjculligan', 0, 'LEGISLATION', 'EH'): [721.3333333333334,
#   1732.6666666666667,
#   0.04633333333333334],
#  ('kevinjculligan', 0, 'LEGISLATION', 'AH'): [516.6666666666666,
#   1794.3333333333333,
#   0.03366666666666667],
#  ('kevinjculligan', 0, 'LEGISLATION', 'EY'): [623.3333333333334,
#   1937.3333333333333,
#   0.050333333333333334],
#  ('kevinjculligan', 0, 'NEEDED', 'IY'): [543.5, 2541.5, 0.084],
#  ('kevinjculligan', 0, 'NEEDED', 'AH'): [560.0, 2065.5, 0.0745],
#  ('kevinjculligan', 0, 'SECURE', 'IH'): [549.0, 2370.0, 0.03],
#  ('kevinjculligan', 0, 'SECURE', 'UH'): [537.0, 1466.0, 0.06],
#  ('kevinjculligan', 0, 'GUARANTEES', 'EH'): [673.0, 1907.0, 0.069],
#  ('kevinjculligan', 0, 'GUARANTEES', 'AH'): [566.0, 1622.0, 0.029],
#  ('kevinjculligan', 0, 'GUARANTEES', 'IY'): [476.0, 2203.0, 0.069],
#  ('kevinjculligan', 0, 'IN', 'IH'): [592.0,
#   2247.6666666666665,
#   0.1366666666666667],
#  ('kevinjculligan', 0, 'EXPOSITION', 'EH'): [770.0, 1653.0, 0.06],
#  ('kevinjculligan', 0, 'EXPOSITION', 'AH'): [539.0, 1746.0, 0.03],
#  ('kevinjculligan', 0, 'EXPOSITION', 'IH'): [611.0, 1827.0, 0.06],
#  ('kevinjculligan', 0, 'STANDARD', 'AE'): [741.0, 2135.5, 0.11499999999999999],
#  ('kevinjculligan', 0, 'STANDARD', 'ER'): [629.5, 1466.0, 0.1],
#  ('kevinjculligan', 0, 'EXPLAINED', 'IH'): [634.0, 2033.0, 0.1],
#  ('kevinjculligan', 0, 'EXPLAINED', 'EY'): [728.0, 1974.0, 0.11],
#  ('kevinjculligan', 0, 'SUBJECT', 'AH'): [772.0, 1326.0, 0.09],
#  ('kevinjculligan', 0, 'SUBJECT', 'IH'): [586.0, 1765.0, 0.08],
#  ('kevinjculligan', 0, 'CHALLENGE', 'AE'): [906.0, 1695.0, 0.09],
#  ('kevinjculligan', 0, 'CHALLENGE', 'AH'): [735.0, 1359.0, 0.031],
#  ('kevinjculligan', 0, 'ALTER', 'AO'): [740.0, 651.0, 0.15],
#  ('kevinjculligan', 0, 'ALTER', 'ER'): [589.0, 1427.0, 0.139],
#  ('kevinjculligan', 0, 'ANY', 'EH'): [778.0, 1628.0, 0.0755],
#  ('kevinjculligan', 0, 'ANY', 'IY'): [831.0, 1997.0, 0.0595],
#  ('kevinjculligan', 0, 'IT', 'AH'): [810.0, 1305.0, 0.27],
#  ('kevinjculligan', 0, 'IT', 'IH'): [547.0, 2245.0, 0.1],
#  ('kevinjculligan', 0, 'PROPORTIONAL', 'AH'): [686.0, 1028.0, 0.031],
#  ('kevinjculligan', 0, 'PROPORTIONAL', 'AO'): [612.0, 908.0, 0.09],
#  ('kevinjculligan', 0, 'LEGITIMATE', 'IH'): [605.0, 1871.0, 0.05],
#  ('kevinjculligan', 0, 'DESIGNED', 'AH'): [454.0, 1908.0, 0.03],
#  ('kevinjculligan', 0, 'DESIGNED', 'AY'): [1004.0, 1263.0, 0.19],
#  ('kevinjculligan', 0, 'PREVENT', 'IH'): [558.0, 1612.5, 0.03],
#  ('kevinjculligan', 0, 'PREVENT', 'EH'): [757.0, 1968.0, 0.14500000000000002],
#  ('kevinjculligan', 0, 'RECENTLY', 'IY'): [552.0, 2734.0, 0.07],
#  ('kevinjculligan', 0, 'RECENTLY', 'AH'): [459.0, 1379.0, 0.03],
#  ('kevinjculligan', 0, 'OBSERVED', 'AH'): [558.0, 1539.0, 0.03],
#  ('kevinjculligan', 0, 'OBSERVED', 'ER'): [630.0, 1592.0, 0.15],
#  ('kevinjculligan', 0, 'INSTANCE', 'IH'): [602.0, 2062.0, 0.0655],
#  ('kevinjculligan', 0, 'INSTANCE', 'AH'): [502.5,
#   1415.5,
#   0.035500000000000004],
#  ('kevinjculligan', 0, 'DETERMINE', 'AH'): [522.0, 1494.5, 0.0295],
#  ('kevinjculligan', 0, 'DETERMINE', 'ER'): [648.0, 1645.0, 0.07],
#  ('kevinjculligan', 0, 'CONCLUSIONS', 'AH'): [567.0, 1677.0, 0.031],
#  ('kevinjculligan', 0, 'CONCLUSIONS', 'UW'): [492.0, 1469.0, 0.06],
#  ('kevinjculligan', 0, 'ENTITLED', 'EH'): [833.0, 1925.0, 0.029],
#  ('kevinjculligan', 0, 'ENTITLED', 'AH'): [719.0, 1846.0, 0.031],
#  ('kevinjculligan', 0, 'DEFERENCE', 'EH'): [671.0, 1803.0, 0.1],
#  ('kevinjculligan', 0, 'DEFERENCE', 'ER'): [656.0, 1756.0, 0.03],
#  ('kevinjculligan', 0, 'DEFERENCE', 'AH'): [706.0, 1693.0, 0.049],
#  ('kevinjculligan', 0, 'QUESTION', 'EH'): [729.8, 1639.2, 0.0538],
#  ('kevinjculligan', 0, 'QUESTION', 'AH'): [562.4, 1898.6, 0.0358],
#  ('kevinjculligan', 0, 'ABOUT', 'AH'): [581.5, 1517.5, 0.03075],
#  ('kevinjculligan', 0, 'ABOUT', 'AW'): [768.75, 1506.25, 0.085],
#  ('kevinjculligan', 0, 'LEGITIMACY', 'AH'): [609.0, 1506.0, 0.03],
#  ('kevinjculligan', 0, 'LEGITIMACY', 'IY'): [485.0, 2657.0, 0.25],
#  ('kevinjculligan', 0, 'OBJECTIVE', 'AH'): [555.0, 2213.0, 0.03],
#  ('kevinjculligan', 0, 'OBJECTIVE', 'EH'): [806.0, 1747.0, 0.1],
#  ('kevinjculligan', 0, 'OBJECTIVE', 'IH'): [521.0, 2256.0, 0.09],
#  ('kevinjculligan', 0, 'UNDERLIES', 'AH'): [768.0, 1041.0, 0.12],
#  ('kevinjculligan', 0, 'UNDERLIES', 'ER'): [563.0, 1465.0, 0.09],
#  ('kevinjculligan', 0, 'UNDERLIES', 'AY'): [817.0, 1193.0, 0.22],
#  ('kevinjculligan', 0, 'ENACTED', 'EH'): [566.0, 1617.0, 0.029],
#  ('kevinjculligan', 0, 'ENACTED', 'AE'): [896.0, 1783.0, 0.12],
#  ('kevinjculligan', 0, 'ENACTED', 'AH'): [499.0, 2212.0, 0.04],
#  ('kevinjculligan', 0, 'NINETEEN', 'AY'): [816.5, 1549.5, 0.095],
#  ('kevinjculligan', 0, 'NINETEEN', 'IY'): [499.0, 2538.0, 0.05],
#  ('kevinjculligan', 0, 'DETER', 'AH'): [471.0, 1810.0, 0.05],
#  ('kevinjculligan', 0, 'DETER', 'ER'): [608.0, 1573.0, 0.11],
#  ('kevinjculligan', 0, 'DEPRIVING', 'AH'): [567.0, 2313.0, 0.05],
#  ('kevinjculligan', 0, 'DEPRIVING', 'IH'): [517.0, 2168.0, 0.03],
#  ('kevinjculligan', 0, 'OWNERS', 'OW'): [642.5, 1751.0, 0.085],
#  ('kevinjculligan', 0, 'OWNERS', 'ER'): [530.0, 1483.0, 0.0605],
#  ('kevinjculligan', 0, 'TOTAL', 'OW'): [766.0, 972.0, 0.17],
#  ('kevinjculligan', 0, 'TOTAL', 'AH'): [704.0, 2012.0, 0.031],
#  ('kevinjculligan', 0, 'PROPERTY', 'AA'): [898.0666666666667,
#   1146.3333333333333,
#   0.1072],
#  ('kevinjculligan', 0, 'PROPERTY', 'ER'): [531.5333333333333,
#   1496.9333333333334,
#   0.05473333333333334],
#  ('kevinjculligan', 0, 'PROPERTY', 'IY'): [536.8333333333334,
#   2500.25,
#   0.12666666666666668],
#  ('kevinjculligan', 0, 'SECURED', 'IH'): [483.0, 1879.0, 0.03],
#  ('kevinjculligan', 0, 'SECURED', 'UH'): [516.0, 977.0, 0.09],
#  ('kevinjculligan', 0, 'EXCLUDE', 'IH'): [506.75, 1814.5, 0.032],
#  ('kevinjculligan', 0, 'EXCLUDE', 'UW'): [513.5, 1085.75, 0.10075],
#  ('kevinjculligan', 0, 'OTHERS', 'AH'): [699.25, 1265.75, 0.06525],
#  ('kevinjculligan', 0, 'OTHERS', 'ER'): [541.5, 1962.0, 0.05425],
#  ('kevinjculligan', 0, 'INCLUDING', 'IH'): [528.5, 2317.5, 0.035],
#  ('kevinjculligan', 0, 'INCLUDING', 'UW'): [565.5, 1464.0, 0.0605],
#  ('kevinjculligan', 0, 'UNIFORM', 'UW'): [545.5, 1705.0, 0.051],
#  ('kevinjculligan', 0, 'UNIFORM', 'AH'): [608.5, 1214.0, 0.0405],
#  ('kevinjculligan', 0, 'UNIFORM', 'AO'): [666.5, 917.0, 0.0805],
#  ('kevinjculligan', 0, 'PROCEDURES', 'AH'): [1000.0, 1945.0, 0.029],
#  ('kevinjculligan', 0, 'PROCEDURES', 'IY'): [472.0, 2341.0, 0.109],
#  ('kevinjculligan', 0, 'PROCEDURES', 'ER'): [521.0, 1881.0, 0.059],
#  ('kevinjculligan', 0, 'REMEDIES', 'EH'): [742.6666666666666,
#   1598.0,
#   0.06333333333333334],
#  ('kevinjculligan', 0, 'REMEDIES', 'AH'): [554.3333333333334,
#   1772.3333333333333,
#   0.033],
#  ('kevinjculligan', 0, 'REMEDIES', 'IY'): [486.3333333333333,
#   2258.0,
#   0.05333333333333334],
#  ('kevinjculligan', 0, 'CORRECT', 'ER'): [633.4, 1461.2, 0.09620000000000002],
#  ('kevinjculligan', 0, 'CORRECT', 'EH'): [734.4, 1782.0, 0.07360000000000001],
#  ('kevinjculligan', 0, 'SCALIA', 'AA'): [522.5, 1039.0, 0.03025],
#  ('kevinjculligan', 0, 'SCALIA', 'IY'): [528.0,
#   2119.6666666666665,
#   0.1396666666666667],
#  ('kevinjculligan', 0, 'SCALIA', 'AH'): [623.0, 1671.0, 0.03],
#  ('kevinjculligan', 0, 'AT', 'AE'): [991.0, 2005.0, 0.14],
#  ('kevinjculligan', 0, 'AT', 'AH'): [921.0, 1156.0, 0.32],
#  ('kevinjculligan', 0, 'PROBLEM', 'AA'): [938.0, 1104.0, 0.135],
#  ('kevinjculligan', 0, 'PROBLEM', 'AH'): [699.5, 1550.0, 0.15999999999999998],
#  ('kevinjculligan', 0, 'CONSIDERED', 'AH'): [506.5, 1842.5, 0.03],
#  ('kevinjculligan', 0, 'CONSIDERED', 'IH'): [608.5, 1733.25, 0.04225],
#  ('kevinjculligan', 0, 'CONSIDERED', 'ER'): [557.5, 1738.5, 0.07775],
#  ('kevinjculligan', 0, 'NUMBER', 'AH'): [831.0, 1276.0, 0.05],
#  ('kevinjculligan', 0, 'NUMBER', 'ER'): [625.0, 1305.0, 0.21],
#  ('kevinjculligan', 0, 'REPORTED', 'AH'): [536.0, 1963.0, 0.03],
#  ('kevinjculligan', 0, 'REPORTED', 'AO'): [554.0, 270.0, 0.1],
#  ('kevinjculligan', 0, 'INVOLVED', 'IH'): [542.0, 1625.0, 0.03],
#  ('kevinjculligan', 0, 'INVOLVED', 'AA'): [861.5, 1022.0, 0.165],
#  ('kevinjculligan', 0, 'SPONSORED', 'AA'): [817.0, 906.0, 0.08],
#  ('kevinjculligan', 0, 'SPONSORED', 'ER'): [517.0, 1933.0, 0.04],
#  ('kevinjculligan', 0, 'BELIEVE', 'AH'): [559.4, 1303.0, 0.030199999999999998],
#  ('kevinjculligan', 0, 'BELIEVE', 'IY'): [500.4, 2491.0, 0.1344],
#  ('kevinjculligan', 0, 'THATS', 'AE'): [787.0, 1530.0, 0.12],
#  ('kevinjculligan', 0, 'ALSO', 'AO'): [752.0, 1054.0, 0.075],
#  ('kevinjculligan', 0, 'ALSO', 'OW'): [760.5, 1492.0, 0.1395],
#  ('kevinjculligan', 0, 'TESTIMONY', 'EH'): [602.0, 1574.5, 0.065],
#  ('kevinjculligan', 0, 'TESTIMONY', 'AH'): [645.0, 1248.5, 0.03],
#  ('kevinjculligan', 0, 'TESTIMONY', 'OW'): [782.0, 920.0, 0.07],
#  ('kevinjculligan', 0, 'TESTIMONY', 'IY'): [534.5, 2322.0, 0.055],
#  ('kevinjculligan', 0, 'HONOR', 'AA'): [838.4, 1276.1, 0.078],
#  ('kevinjculligan', 0, 'HONOR', 'ER'): [647.9, 1561.7, 0.1409],
#  ('kevinjculligan', 0, 'INFRINGEMENT', 'IH'): [682.0, 1836.0, 0.06],
#  ('kevinjculligan', 0, 'INFRINGEMENT', 'AH'): [576.0, 1550.0, 0.03],
#  ('kevinjculligan', 0, 'EXPECTED', 'IH'): [873.0, 1871.0, 0.07],
#  ('kevinjculligan', 0, 'EXPECTED', 'EH'): [775.0, 1684.0, 0.08],
#  ('kevinjculligan', 0, 'EXPECTED', 'AH'): [507.0, 1909.0, 0.04],
#  ('kevinjculligan', 0, 'INCREASE', 'IH'): [515.0, 1646.0, 0.03],
#  ('kevinjculligan', 0, 'INCREASE', 'IY'): [494.0, 2358.0, 0.11],
#  ('kevinjculligan', 0, 'COMMERCIALIZE', 'AH'): [641.0, 1102.0, 0.039],
#  ('kevinjculligan', 0, 'COMMERCIALIZE', 'ER'): [721.0, 1288.0, 0.121],
#  ('kevinjculligan', 0, 'COMMERCIALIZE', 'AY'): [826.0, 1410.0, 0.119],
#  ('kevinjculligan', 0, 'GOING', 'OW'): [707.0, 972.0, 0.12],
#  ('kevinjculligan', 0, 'GOING', 'IH'): [738.0, 1633.0, 0.04],
#  ('kevinjculligan', 0, 'BECOME', 'IH'): [462.0, 2408.0, 0.03],
#  ('kevinjculligan', 0, 'BECOME', 'AH'): [810.0, 1314.0, 0.08],
#  ('kevinjculligan', 0, 'IN', 'AH'): [611.0, 1785.0, 0.04],
#  ('kevinjculligan', 0, 'PATENTS', 'AE'): [897.2, 1977.0, 0.11380000000000001],
#  ('kevinjculligan', 0, 'PATENTS', 'AH'): [536.0, 1864.0, 0.0322],
#  ('kevinjculligan', 0, 'FREQUENCY', 'IY'): [500.0, 2037.0, 0.05],
#  ('kevinjculligan', 0, 'FREQUENCY', 'AH'): [547.0, 1627.0, 0.03],
#  ('kevinjculligan', 0, 'GRANTED', 'AE'): [870.0, 2065.0, 0.1],
#  ('kevinjculligan', 0, 'GRANTED', 'AH'): [494.0, 2021.0, 0.04],
#  ('kevinjculligan', 0, 'ELEVENTH', 'AH'): [614.0, 1555.0, 0.04],
#  ('kevinjculligan', 0, 'ELEVENTH', 'EH'): [806.0, 1418.0, 0.05],
#  ('kevinjculligan', 0, 'IMMUNITY', 'IH'): [553.5, 1548.5, 0.0295],
#  ('kevinjculligan', 0, 'IMMUNITY', 'UW'): [538.0, 1881.0, 0.0295],
#  ('kevinjculligan', 0, 'IMMUNITY', 'AH'): [477.5, 1861.0, 0.03],
#  ('kevinjculligan', 0, 'IMMUNITY', 'IY'): [471.5, 2336.0, 0.0895],
#  ('kevinjculligan', 0, 'GROWING', 'OW'): [784.0, 1083.0, 0.13],
#  ('kevinjculligan', 0, 'GROWING', 'IH'): [631.0, 1945.0, 0.05],
#  ('kevinjculligan', 0, 'DISRESPECT', 'IH'): [605.0, 1775.0, 0.05],
#  ('kevinjculligan', 0, 'DISRESPECT', 'AH'): [483.0, 1984.0, 0.03],
#  ('kevinjculligan', 0, 'DISRESPECT', 'EH'): [848.0, 1759.0, 0.08],
#  ('kevinjculligan', 0, 'SITUATIONS', 'IH'): [513.0, 1849.0, 0.049],
#  ('kevinjculligan', 0, 'SITUATIONS', 'UW'): [503.0, 1417.0, 0.15],
#  ('kevinjculligan', 0, 'SITUATIONS', 'EY'): [621.0, 1918.0, 0.04],
#  ('kevinjculligan', 0, 'SITUATIONS', 'AH'): [611.0, 1726.0, 0.041],
#  ('kevinjculligan', 0, 'INTENTIONALLY', 'IH'): [507.0, 2410.0, 0.09],
#  ('kevinjculligan', 0, 'INTENTIONALLY', 'EH'): [883.0, 2186.0, 0.09],
#  ('kevinjculligan', 0, 'INTENTIONALLY', 'AH'): [630.0, 1033.0, 0.031],
#  ('kevinjculligan', 0, 'INTENTIONALLY', 'IY'): [418.0, 2373.0, 0.481],
#  ('kevinjculligan', 0, 'DISREGARD', 'IH'): [538.0, 1625.0, 0.031],
#  ('kevinjculligan', 0, 'DISREGARD', 'AA'): [754.0, 975.0, 0.17],
#  ('kevinjculligan', 0, 'CONTEXT', 'AA'): [946.5, 1382.0, 0.09],
#  ('kevinjculligan', 0, 'CONTEXT', 'EH'): [653.5, 1763.0, 0.040499999999999994],
#  ('kevinjculligan', 0, 'CERTAINLY', 'ER'): [696.0, 1531.0, 0.11],
#  ('kevinjculligan', 0, 'CERTAINLY', 'AH'): [532.0, 1681.0, 0.03],
#  ('kevinjculligan', 0, 'CERTAINLY', 'IY'): [544.0, 2494.0, 0.12],
#  ('kevinjculligan', 0, 'BASIS', 'EY'): [616.0, 2007.0, 0.12],
#  ('kevinjculligan', 0, 'BASIS', 'IH'): [551.0, 1566.0, 0.05],
#  ('kevinjculligan', 0, 'CONCLUDED', 'AH'): [498.0, 1905.0, 0.04],
#  ('kevinjculligan', 0, 'CONCLUDED', 'UW'): [548.0, 1421.0, 0.1],
#  ('kevinjculligan', 0, 'PROCESS', 'AA'): [860.2, 1092.8, 0.10200000000000001],
#  ('kevinjculligan', 0, 'PROCESS', 'EH'): [642.4, 1530.4, 0.07980000000000001],
#  ('kevinjculligan', 0, 'MEASURE', 'EH'): [790.0, 1866.0, 0.1],
#  ('kevinjculligan', 0, 'MEASURE', 'ER'): [488.0, 1823.0, 0.041],
#  ('kevinjculligan', 0, 'THE', 'AH'): [664.6666666666666,
#   1631.6666666666667,
#   0.042666666666666665],
#  ('kevinjculligan', 0, 'LEGISLATIVE', 'EH'): [726.0, 1853.0, 0.049],
#  ('kevinjculligan', 0, 'HISTORY', 'IH'): [573.0, 1978.0, 0.07],
#  ('kevinjculligan', 0, 'HISTORY', 'IY'): [479.0, 1878.0, 0.371],
#  ('kevinjculligan', 0, 'LOOKING', 'UH'): [714.0, 889.0, 0.03],
#  ('kevinjculligan', 0, 'LOOKING', 'IH'): [651.0, 1478.0, 0.03],
#  ('kevinjculligan', 0, 'PREDICATE', 'EH'): [798.0, 1670.0, 0.07],
#  ('kevinjculligan', 0, 'PREDICATE', 'AH'): [656.0, 2019.0, 0.039],
#  ('kevinjculligan', 0, 'OF', 'AH'): [791.75, 1267.0, 0.40249999999999997],
#  ('kevinjculligan', 0, 'AUTHORITY', 'IY'): [457.5,
#   2495.5,
#   0.16999999999999998],
#  ('kevinjculligan', 0, 'UNDER', 'AH'): [703.6666666666666,
#   1470.5,
#   0.035166666666666666],
#  ('kevinjculligan', 0, 'UNDER', 'ER'): [543.5,
#   1574.3333333333333,
#   0.053166666666666675],
#  ('kevinjculligan', 0, 'PROTECT', 'ER'): [576.5, 1825.0, 0.0655],
#  ('kevinjculligan', 0, 'PROTECT', 'EH'): [792.6666666666666,
#   1868.6666666666667,
#   0.07966666666666668],
#  ('kevinjculligan', 0, 'WITHOUT', 'IH'): [563.5, 1432.5, 0.0305],
#  ('kevinjculligan', 0, 'WITHOUT', 'AW'): [852.5, 1624.5, 0.14],
#  ('kevinjculligan', 0, 'REGARDLESS', 'AH'): [568.0, 1559.0, 0.03],
#  ('kevinjculligan', 0, 'REGARDLESS', 'AA'): [826.0, 924.0, 0.129],
#  ('kevinjculligan', 0, 'ORIGIN', 'AO'): [708.0, 1052.0, 0.18],
#  ('kevinjculligan', 0, 'ORIGIN', 'AH'): [537.0, 1719.0, 0.039],
#  ('kevinjculligan', 0, 'FEDERALLY', 'EH'): [765.0, 1614.0, 0.06],
#  ('kevinjculligan', 0, 'FEDERALLY', 'ER'): [545.0, 1400.0, 0.03],
#  ('kevinjculligan', 0, 'FEDERALLY', 'AH'): [575.0, 1191.0, 0.029],
#  ('kevinjculligan', 0, 'FEDERALLY', 'IY'): [503.0, 2584.0, 0.049],
#  ('kevinjculligan', 0, 'CREATED', 'IY'): [585.0, 1954.0, 0.031],
#  ('kevinjculligan', 0, 'CREATED', 'EY'): [616.0, 1980.0, 0.03],
#  ('kevinjculligan', 0, 'CREATED', 'AH'): [538.0, 1857.0, 0.051],
#  ('kevinjculligan', 0, 'CERTAIN', 'ER'): [623.5, 1583.5, 0.095],
#  ('kevinjculligan', 0, 'CERTAIN', 'AH'): [501.5, 1516.5, 0.03],
#  ('kevinjculligan', 0, 'DIMENSIONS', 'IH'): [566.0, 1748.0, 0.04],
#  ('kevinjculligan', 0, 'DIMENSIONS', 'EH'): [937.0, 1999.0, 0.08],
#  ('kevinjculligan', 0, 'DIMENSIONS', 'AH'): [498.0, 1906.0, 0.04],
#  ('kevinjculligan', 0, 'ESSENTIAL', 'AH'): [544.0, 1505.0, 0.06],
#  ('kevinjculligan', 0, 'ESSENTIAL', 'EH'): [859.0, 1745.0, 0.07],
#  ('kevinjculligan', 0, 'VERY', 'EH'): [614.0, 1870.75, 0.052750000000000005],
#  ('kevinjculligan', 0, 'VERY', 'IY'): [561.5, 2083.0, 0.08524999999999999],
#  ('kevinjculligan', 0, 'UNIQUE', 'UW'): [583.0, 1632.0, 0.0405],
#  ('kevinjculligan', 0, 'UNIQUE', 'IY'): [503.5, 2625.5, 0.135],
#  ('kevinjculligan', 0, 'SPECIAL', 'EH'): [771.5, 1689.0, 0.07],
#  ('kevinjculligan', 0, 'SPECIAL', 'AH'): [648.5, 1499.0, 0.0305],
#  ('kevinjculligan', 0, 'ATTEMPT', 'AH'): [675.0, 1823.0, 0.09],
#  ('kevinjculligan', 0, 'ATTEMPT', 'EH'): [850.0, 2077.0, 0.07],
#  ('kevinjculligan', 0, 'CARRY', 'AE'): [846.0, 1755.0, 0.11],
#  ('kevinjculligan', 0, 'CARRY', 'IY'): [538.0, 2354.0, 0.03],
#  ('kevinjculligan', 0, 'RECOGNIZED', 'EH'): [806.3333333333334,
#   1745.3333333333333,
#   0.067],
#  ('kevinjculligan', 0, 'RECOGNIZED', 'AH'): [508.0, 2352.6666666666665, 0.03],
#  ('kevinjculligan', 0, 'DECISIONS', 'AH'): [480.5, 1767.0, 0.0295],
#  ('kevinjculligan', 0, 'DECISIONS', 'IH'): [557.0, 1904.0, 0.03],
#  ('kevinjculligan', 0, 'EXTENDING', 'IH'): [492.0, 2268.0, 0.03],
#  ('kevinjculligan', 0, 'EXTENDING', 'EH'): [770.0, 1722.0, 0.06],
#  ('kevinjculligan', 0, 'OVER', 'OW'): [697.0, 946.0, 0.15],
#  ('kevinjculligan', 0, 'OVER', 'ER'): [614.0, 1470.0, 0.08],
#  ('kevinjculligan', 0, 'TAKINGS', 'EY'): [630.0, 2329.0, 0.12],
#  ('kevinjculligan', 0, 'TAKINGS', 'IH'): [520.0, 2615.0, 0.05],
#  ('kevinjculligan', 0, 'UNITED', 'UW'): [569.0, 2198.0, 0.03],
#  ('kevinjculligan', 0, 'UNITED', 'AH'): [528.0, 2016.0, 0.04],
#  ('kevinjculligan', 0, 'GOVERNMENT', 'AH'): [544.0, 2041.0, 0.03],
#  ('kevinjculligan', 0, 'GOVERNMENT', 'ER'): [596.0, 1306.0, 0.06],
#  ('kevinjculligan', 0, 'CONSTITUTE', 'AA'): [936.0, 1269.0, 0.251],
#  ('kevinjculligan', 0, 'CONSTITUTE', 'AH'): [856.0, 1335.0, 0.089],
#  ('kevinjculligan', 0, 'CONSTITUTE', 'UW'): [499.0, 2193.0, 0.1],
#  ('kevinjculligan', 0, 'CONSTITUTIONALLY', 'AA'): [855.0, 1319.0, 0.09],
#  ('kevinjculligan', 0, 'CONSTITUTIONALLY', 'AH'): [612.0, 1301.0, 0.031],
#  ('kevinjculligan', 0, 'CONSTITUTIONALLY', 'UW'): [559.0, 1937.0, 0.099],
#  ('kevinjculligan', 0, 'COGNIZABLE', 'AA'): [871.0, 1279.0, 0.12],
#  ('kevinjculligan', 0, 'COGNIZABLE', 'AH'): [693.0, 1423.0, 0.031],
#  ('kevinjculligan', 0, 'DEPRIVATION', 'EH'): [701.0, 1688.0, 0.09],
#  ('kevinjculligan', 0, 'DEPRIVATION', 'AH'): [660.0, 1716.0, 0.041],
#  ('kevinjculligan', 0, 'DEPRIVATION', 'EY'): [669.0, 1953.0, 0.129],
#  ('kevinjculligan', 0, 'LIMITS', 'IH'): [688.0, 1631.0, 0.06],
#  ('kevinjculligan', 0, 'LIMITS', 'AH'): [528.0, 1620.0, 0.05],
#  ('kevinjculligan', 0, 'CONGRESSS', 'AA'): [965.0, 1283.0, 0.07],
#  ('kevinjculligan', 0, 'CONGRESSS', 'AH'): [529.0, 1815.0, 0.04],
#  ('kevinjculligan', 0, 'CREATE', 'IY'): [507.3333333333333,
#   2353.6666666666665,
#   0.05333333333333334],
#  ('kevinjculligan', 0, 'CREATE', 'EY'): [615.0, 2343.0, 0.18000000000000002],
#  ('kevinjculligan', 0, 'RESPECT', 'AH'): [460.5, 1971.5, 0.03],
#  ('kevinjculligan', 0, 'RESPECT', 'EH'): [755.0, 1505.0, 0.0505],
#  ('kevinjculligan', 0, 'COPYRIGHTS', 'AA'): [1116.0, 1411.0, 0.12],
#  ('kevinjculligan', 0, 'COPYRIGHTS', 'IY'): [511.0, 2049.0, 0.1],
#  ('kevinjculligan', 0, 'COPYRIGHTS', 'AY'): [773.0, 1458.0, 0.12],
#  ('kevinjculligan', 0, 'ABROGATING', 'AE'): [873.0, 1899.0, 0.13],
#  ('kevinjculligan', 0, 'ABROGATING', 'AH'): [556.0, 1955.0, 0.039],
#  ('kevinjculligan', 0, 'ABROGATING', 'EY'): [596.0, 2232.0, 0.121],
#  ('kevinjculligan', 0, 'ABROGATING', 'IH'): [590.0, 2415.0, 0.041],
#  ('kevinjculligan', 0, 'SOVEREIGN', 'AA'): [866.5,
#   1281.5,
#   0.11049999999999999],
#  ('kevinjculligan', 0, 'SOVEREIGN', 'AH'): [568.0, 1568.5, 0.029],
#  ('kevinjculligan', 0, 'SIGNIFICANT', 'IH'): [541.0, 2009.0, 0.031],
#  ('kevinjculligan', 0, 'SIGNIFICANT', 'AH'): [546.0, 2067.0, 0.041],
#  ('kevinjculligan', 0, 'LIKELIHOOD', 'AY'): [915.0, 1347.0, 0.11],
#  ('kevinjculligan', 0, 'LIKELIHOOD', 'IY'): [482.0, 2437.0, 0.099],
#  ('kevinjculligan', 0, 'LIKELIHOOD', 'UH'): [614.0, 1410.0, 0.13],
#  ('kevinjculligan', 0, 'PERSONS', 'ER'): [622.0,
#   1421.3333333333333,
#   0.11333333333333333],
#  ('kevinjculligan', 0, 'PERSONS', 'AH'): [493.0, 1704.6666666666667, 0.03],
#  ('kevinjculligan', 0, 'ARISES', 'ER'): [596.0, 1344.0, 0.13],
#  ('kevinjculligan', 0, 'ARISES', 'AH'): [536.0, 1407.0, 0.03],
#  ('kevinjculligan', 0, 'SYSTEM', 'IH'): [560.0, 1783.0, 0.051],
#  ('kevinjculligan', 0, 'SYSTEM', 'AH'): [557.0, 1597.0, 0.039],
#  ('kevinjculligan', 0, 'EXCHANGE', 'IH'): [608.0, 2355.0, 0.041],
#  ('kevinjculligan', 0, 'EXCHANGE', 'EY'): [786.0, 2313.0, 0.159],
#  ('kevinjculligan', 0, 'DISCLOSURE', 'IH'): [512.0, 1857.0, 0.049],
#  ('kevinjculligan', 0, 'DISCLOSURE', 'OW'): [717.0, 1101.0, 0.099],
#  ('kevinjculligan', 0, 'DISCLOSURE', 'ER'): [573.0, 1452.0, 0.26],
#  ('kevinjculligan', 0, 'INVENTIVE', 'IH'): [534.0, 1620.0, 0.031],
#  ('kevinjculligan', 0, 'INVENTIVE', 'EH'): [750.0, 1781.0, 0.08],
#  ('kevinjculligan', 0, 'CONTRIBUTION', 'AA'): [813.0, 1405.0, 0.09],
#  ('kevinjculligan', 0, 'CONTRIBUTION', 'AH'): [637.0, 1742.0, 0.05],
#  ('kevinjculligan', 0, 'CONTRIBUTION', 'UW'): [536.0, 2104.0, 0.08],
#  ('kevinjculligan', 0, 'INVENTOR', 'IH'): [571.0, 2234.0, 0.031],
#  ('kevinjculligan', 0, 'INVENTOR', 'EH'): [771.0, 1783.0, 0.071],
#  ('kevinjculligan', 0, 'INVENTOR', 'ER'): [526.0, 1825.0, 0.07],
#  ('kevinjculligan', 0, 'LIMITED', 'IH'): [668.0, 1763.0, 0.031],
#  ('kevinjculligan', 0, 'LIMITED', 'AH'): [496.0, 1870.0, 0.039],
#  ('kevinjculligan', 0, 'ARGUMENT', 'AA'): [731.5, 1896.0, 0.0545],
#  ('kevinjculligan', 0, 'ARGUMENT', 'AH'): [709.0, 1911.5, 0.03],
#  ('kevinjculligan', 0, 'NATURE', 'EY'): [661.5, 2137.0, 0.12],
#  ('kevinjculligan', 0, 'NATURE', 'ER'): [595.0, 1678.5, 0.09],
#  ('kevinjculligan', 0, 'GIVES', 'IH'): [543.0, 2044.0, 0.1],
#  ('kevinjculligan', 0, 'ANALOGOUS', 'AH'): [572.0, 1689.0, 0.03],
#  ('kevinjculligan', 0, 'ANALOGOUS', 'AE'): [910.0, 1806.0, 0.04],
#  ('kevinjculligan', 0, 'ARGUMENTS', 'AA'): [791.0, 909.0, 0.14],
#  ('kevinjculligan', 0, 'ARGUMENTS', 'AH'): [574.0, 1717.0, 0.03],
#  ('kevinjculligan', 0, 'PREDICATED', 'EH'): [691.0, 1583.0, 0.04],
#  ('kevinjculligan', 0, 'PREDICATED', 'AH'): [550.0, 1870.0, 0.059],
#  ('kevinjculligan', 0, 'PREDICATED', 'EY'): [517.0, 2380.0, 0.07],
#  ('kevinjculligan', 0, 'NOTION', 'OW'): [759.0, 1464.0, 0.109],
#  ('kevinjculligan', 0, 'NOTION', 'AH'): [479.0, 1652.0, 0.04],
#  ('kevinjculligan', 0, 'DEPRIVE', 'AH'): [529.0, 1536.0, 0.039],
#  ('kevinjculligan', 0, 'DEPRIVE', 'AY'): [937.0, 1279.0, 0.201],
#  ('kevinjculligan', 0, 'UNDERSTAND', 'AH'): [765.0, 1743.0, 0.0395],
#  ('kevinjculligan', 0, 'UNDERSTAND', 'ER'): [534.0, 1759.0, 0.045],
#  ('kevinjculligan', 0, 'UNDERSTAND', 'AE'): [723.0,
# ...
#  ('kevinjculligan', 0, 'NATIONAL', 'AE'): [866.0, 2016.0, 0.12],
#  ('kevinjculligan', 0, 'NATIONAL', 'AH'): [704.0, 1735.0, 0.04],
#  ('kevinjculligan', 0, 'UNIFORMITY', 'UW'): [520.0, 1938.0, 0.06],
#  ('kevinjculligan', 0, 'UNIFORMITY', 'AH'): [599.0, 1663.0, 0.039],
#  ('kevinjculligan', 0, 'UNIFORMITY', 'AO'): [679.0, 952.0, 0.121],
#  ('kevinjculligan', 0, 'UNIFORMITY', 'IY'): [473.0, 2799.0, 0.19],
#  ('kevinjculligan', 0, 'INTELLECTUAL', 'IH'): [560.0, 1791.0, 0.041],
#  ('kevinjculligan', 0, 'INTELLECTUAL', 'AH'): [618.0, 1844.0, 0.031],
#  ('kevinjculligan', 0, 'INTELLECTUAL', 'EH'): [714.0, 1672.0, 0.04],
#  ('kevinjculligan', 0, 'INTELLECTUAL', 'UW'): [688.0, 1550.0, 0.03],
#  ('kevinjculligan', 0, 'EIGHTEEN', 'EY'): [592.0, 2050.0, 0.14],
#  ('kevinjculligan', 0, 'EIGHTEEN', 'IY'): [547.0, 2910.0, 0.069],
#  ('kevinjculligan', 0, 'HUNDRED', 'AH'): [822.0, 1176.0, 0.081],
#  ('kevinjculligan', 0, 'HUNDRED', 'ER'): [542.0, 1708.0, 0.1],
#  ('kevinjculligan', 0, 'EXCLUSIVE', 'IH'): [487.0, 1535.0, 0.03],
#  ('kevinjculligan', 0, 'EXCLUSIVE', 'UW'): [474.0, 995.0, 0.1],
#  ('kevinjculligan', 0, 'JURISDICTION', 'UH'): [579.0, 1692.0, 0.03],
#  ('kevinjculligan', 0, 'JURISDICTION', 'AH'): [464.0, 1431.0, 0.03],
#  ('kevinjculligan', 0, 'JURISDICTION', 'IH'): [572.0, 1819.0, 0.07],
#  ('kevinjculligan', 0, 'ACTIONS', 'AE'): [878.0, 1567.0, 0.12],
#  ('kevinjculligan', 0, 'ACTIONS', 'AH'): [698.0, 1688.0, 0.04],
#  ('kevinjculligan', 0, 'ARISING', 'ER'): [494.0, 993.0, 0.09],
#  ('kevinjculligan', 0, 'ARISING', 'AY'): [801.0, 1121.0, 0.1],
#  ('kevinjculligan', 0, 'ARISING', 'IH'): [555.0, 2615.0, 0.03],
#  ('kevinjculligan', 0, 'ALLOWED', 'AH'): [657.0, 1124.0, 0.04],
#  ('kevinjculligan', 0, 'ALLOWED', 'AW'): [892.0, 1565.0, 0.19],
#  ('kevinjculligan', 0, 'DEVELOPMENT', 'IH'): [500.0, 1511.0, 0.03],
#  ('kevinjculligan', 0, 'DEVELOPMENT', 'EH'): [710.0, 1322.0, 0.03],
#  ('kevinjculligan', 0, 'DEVELOPMENT', 'AH'): [595.0, 1449.0, 0.03],
#  ('kevinjculligan', 0, 'BODY', 'AA'): [842.0, 1120.0, 0.15],
#  ('kevinjculligan', 0, 'BODY', 'IY'): [521.0, 2189.0, 0.06],
#  ('kevinjculligan', 0, 'RESOLVE', 'IY'): [562.0, 1371.0, 0.03],
#  ('kevinjculligan', 0, 'RESOLVE', 'AA'): [858.0, 1125.0, 0.21],
#  ('kevinjculligan', 0, 'CONSTANT', 'AA'): [917.0, 1331.0, 0.11],
#  ('kevinjculligan', 0, 'CONSTANT', 'AH'): [494.0, 1658.0, 0.03],
#  ('kevinjculligan', 0, 'TENSION', 'EH'): [784.0, 2065.0, 0.09],
#  ('kevinjculligan', 0, 'TENSION', 'AH'): [540.0, 1839.0, 0.05],
#  ('kevinjculligan', 0, 'BETWEEN', 'AH'): [482.0, 1703.0, 0.05],
#  ('kevinjculligan', 0, 'BETWEEN', 'IY'): [536.0, 2370.0, 0.05],
#  ('kevinjculligan', 0, 'ACCESS', 'AE'): [875.0, 1751.0, 0.17],
#  ('kevinjculligan', 0, 'ACCESS', 'EH'): [696.0, 1549.0, 0.16],
#  ('kevinjculligan', 0, 'CONCEIVABLE', 'AH'): [612.0, 868.0, 0.031],
#  ('kevinjculligan', 0, 'CONCEIVABLE', 'IY'): [524.0, 2435.0, 0.121],
#  ('kevinjculligan', 0, 'THAT', 'AE'): [664.0, 1847.0, 0.11],
#  ('kevinjculligan', 0, 'THAT', 'AH'): [396.0, 1388.0, 0.249],
#  ('kevinjculligan', 0, 'FEDERAL', 'ER'): [493.0, 1226.0, 0.03],
#  ('kevinjculligan', 0, 'CIRCUIT', 'ER'): [675.0, 1373.0, 0.15],
#  ('kevinjculligan', 0, 'CIRCUIT', 'AH'): [607.0, 2085.0, 0.04],
#  ('kevinjculligan', 0, 'FACTORS', 'AE'): [918.0, 1737.0, 0.11],
#  ('kevinjculligan', 0, 'FACTORS', 'ER'): [528.0, 1885.0, 0.05],
#  ('kevinjculligan', 0, 'DIFFERING', 'IH'): [637.0, 1831.0, 0.04],
#  ('kevinjculligan', 0, 'STANDARDS', 'AE'): [813.0, 2061.0, 0.11],
#  ('kevinjculligan', 0, 'STANDARDS', 'ER'): [543.0, 1765.0, 0.07],
#  ('kevinjculligan', 0, 'VALIDITY', 'AH'): [577.0, 2027.0, 0.03],
#  ('kevinjculligan', 0, 'VALIDITY', 'IH'): [558.0, 1677.0, 0.03],
#  ('kevinjculligan', 0, 'VALIDITY', 'IY'): [484.0, 2113.0, 0.05],
#  ('kevinjculligan', 0, 'IS', 'IH'): [503.0, 2242.0, 0.11],
#  ('kevinjculligan', 0, 'LITIGATION', 'IH'): [549.0, 1647.0, 0.03],
#  ('kevinjculligan', 0, 'LITIGATION', 'AH'): [508.0, 1661.0, 0.05],
#  ('kevinjculligan', 0, 'LITIGATION', 'EY'): [599.0, 2244.0, 0.11],
#  ('kevinjculligan', 0, 'QUESTIONS', 'EH'): [720.0, 1246.0, 0.06],
#  ('kevinjculligan', 0, 'QUESTIONS', 'AH'): [455.0, 1702.0, 0.03],
#  ('kevinjculligan', 0, 'COMING', 'AH'): [905.0, 1258.0, 0.051],
#  ('kevinjculligan', 0, 'COMING', 'IH'): [559.0, 2264.0, 0.031],
#  ('kevinjculligan', 0, 'AFTER', 'AE'): [699.0, 1807.0, 0.08],
#  ('kevinjculligan', 0, 'AFTER', 'ER'): [480.0, 1726.0, 0.029],
#  ('kevinjculligan', 0, 'REPEATEDLY', 'AH'): [540.0, 2049.0, 0.06],
#  ('kevinjculligan', 0, 'REPEATEDLY', 'IY'): [441.0, 2672.0, 0.1],
#  ('kevinjculligan', 0, 'PROTECT', 'AH'): [547.0, 1693.0, 0.039],
#  ('kevinjculligan', 0, 'VIOLATIONS', 'AH'): [421.0, 1481.0, 0.18],
#  ('kevinjculligan', 0, 'VIOLATIONS', 'EY'): [758.0, 1625.0, 0.08],
#  ('kevinjculligan', 0, 'RESPOND', 'AH'): [554.0, 1676.0, 0.03],
#  ('kevinjculligan', 0, 'RESPOND', 'AA'): [859.0, 1210.0, 0.09],
#  ('kevinjculligan', 0, 'CIRCUMSTANCES', 'ER'): [701.0, 1428.0, 0.1],
#  ('kevinjculligan', 0, 'CIRCUMSTANCES', 'AH'): [476.0, 1800.0, 0.029],
#  ('kevinjculligan', 0, 'CIRCUMSTANCES', 'AE'): [803.0, 2032.0, 0.111],
#  ('sethpwaxman', 0, 'MR', 'IH'): [559.7678571428571,
#   1781.5982142857142,
#   0.03608928571428568],
#  ('sethpwaxman', 0, 'MR', 'ER'): [512.2142857142857,
#   1589.8125,
#   0.08010714285714282],
#  ('sethpwaxman', 0, 'JUSTICE', 'AH'): [495.25, 1694.5, 0.035],
#  ('sethpwaxman', 0, 'CONGRESS', 'AA'): [899.9513513513514,
#   1258.254054054054,
#   0.1267945945945946],
#  ('sethpwaxman', 0, 'CONGRESS', 'AH'): [498.06666666666666,
#   1720.1333333333334,
#   0.04460000000000001],
#  ('sethpwaxman', 0, 'TESTIMONY', 'EH'): [862.7692307692307,
#   1734.2307692307693,
#   0.06869230769230769],
#  ('sethpwaxman', 0, 'TESTIMONY', 'AH'): [570.0769230769231,
#   1515.5384615384614,
#   0.038384615384615385],
#  ('sethpwaxman', 0, 'TESTIMONY', 'OW'): [707.6923076923077,
#   989.1538461538462,
#   0.09146153846153847],
#  ('sethpwaxman', 0, 'TESTIMONY', 'IY'): [538.0,
#   2318.230769230769,
#   0.12000000000000002],
#  ('sethpwaxman', 0, 'REFLECTED', 'AH'): [532.6, 1973.4, 0.05500000000000001],
#  ('sethpwaxman', 0, 'REFLECTED', 'EH'): [875.1, 1594.6, 0.03690000000000001],
#  ('sethpwaxman', 0, 'HEARING', 'IH'): [621.875, 1980.75, 0.05],
#  ('sethpwaxman', 0, 'AND', 'AE'): [724.0, 2122.5, 0.11],
#  ('sethpwaxman', 0, 'TWO', 'UW'): [968.0, 1685.0, 0.11],
#  ('sethpwaxman', 0, 'REPORTS', 'AH'): [662.2, 1243.0, 0.0298],
#  ('sethpwaxman', 0, 'REPORTS', 'AO'): [570.0, 833.0, 0.16060000000000002],
#  ('sethpwaxman', 0, 'COMMITTEE', 'AH'): [528.8888888888889,
#   1659.6666666666667,
#   0.03677777777777777],
#  ('sethpwaxman', 0, 'COMMITTEE', 'IH'): [584.2222222222222,
#   1999.3333333333333,
#   0.060000000000000005],
#  ('sethpwaxman', 0, 'COMMITTEE', 'IY'): [446.0,
#   2348.4444444444443,
#   0.1131111111111111],
#  ('sethpwaxman', 0, 'REPORT', 'IY'): [678.0, 2117.0, 0.041],
#  ('sethpwaxman', 0, 'REPORT', 'AO'): [555.4615384615385,
#   846.6923076923077,
#   0.15084615384615385],
#  ('sethpwaxman', 0, 'SENATE', 'EH'): [704.0, 1821.5, 0.06],
#  ('sethpwaxman', 0, 'SENATE', 'AH'): [645.0, 1937.0, 0.0455],
#  ('sethpwaxman', 0, 'REPORT', 'AH'): [654.6666666666666,
#   1295.0,
#   0.030166666666666675],
#  ('sethpwaxman', 0, 'RECENT', 'IY'): [445.5, 2231.0, 0.0755],
#  ('sethpwaxman', 0, 'RECENT', 'AH'): [596.5, 1781.0, 0.065],
#  ('sethpwaxman', 0, 'UNIVERSITIES', 'UW'): [475.5, 1617.5, 0.0455],
#  ('sethpwaxman', 0, 'UNIVERSITIES', 'IH'): [564.0, 1464.5, 0.035],
#  ('sethpwaxman', 0, 'UNIVERSITIES', 'ER'): [594.5, 1170.5, 0.129],
#  ('sethpwaxman', 0, 'UNIVERSITIES', 'AH'): [498.5, 1888.5, 0.0395],
#  ('sethpwaxman', 0, 'UNIVERSITIES', 'IY'): [419.0, 2470.0, 0.12],
#  ('sethpwaxman', 0, 'OTHER', 'AH'): [796.0780141843971,
#   1254.3475177304965,
#   0.12025531914893611],
#  ('sethpwaxman', 0, 'OTHER', 'ER'): [567.4326241134752,
#   1486.3333333333333,
#   0.09905673758865248],
#  ('sethpwaxman', 0, 'INSTRUMENTALITIES', 'IH'): [608.0, 1600.0, 0.031],
#  ('sethpwaxman', 0, 'INSTRUMENTALITIES', 'AH'): [619.0, 1555.0, 0.03],
#  ('sethpwaxman', 0, 'INSTRUMENTALITIES', 'EH'): [600.5, 1820.0, 0.0395],
#  ('sethpwaxman', 0, 'INSTRUMENTALITIES', 'AE'): [755.0, 2005.5, 0.105],
#  ('sethpwaxman', 0, 'INSTRUMENTALITIES', 'IY'): [466.0, 2200.5, 0.0995],
#  ('sethpwaxman', 0, 'UNPRECEDENTED', 'AH'): [654.0, 1847.0, 0.06],
#  ('sethpwaxman', 0, 'UNPRECEDENTED', 'EH'): [578.0, 1830.0, 0.071],
#  ('sethpwaxman', 0, 'EXTENT', 'IH'): [569.1333333333333,
#   2043.1333333333334,
#   0.046733333333333335],
#  ('sethpwaxman', 0, 'EXTENT', 'EH'): [713.5333333333333,
#   1842.8,
#   0.09066666666666667],
#  ('sethpwaxman', 0, 'BECOME', 'IH'): [422.8333333333333,
#   2259.0,
#   0.06883333333333334],
#  ('sethpwaxman', 0, 'BECOME', 'AH'): [791.0,
#   1162.8333333333333,
#   0.10916666666666668],
#  ('sethpwaxman', 0, 'ACTIVE', 'AE'): [942.6666666666666,
#   1975.5,
#   0.19166666666666665],
#  ('sethpwaxman', 0, 'ACTIVE', 'IH'): [574.3333333333334,
#   1874.0,
#   0.048666666666666664],
#  ('sethpwaxman', 0, 'COMMERCIAL', 'AH'): [638.5263157894736,
#   1251.6842105263158,
#   0.03615789473684211],
#  ('sethpwaxman', 0, 'COMMERCIAL', 'ER'): [631.2105263157895,
#   1178.157894736842,
#   0.12178947368421056],
#  ('sethpwaxman', 0, 'TECHNOLOGY', 'EH'): [803.9375,
#   1753.875,
#   0.05418749999999999],
#  ('sethpwaxman', 0, 'TECHNOLOGY', 'AA'): [1005.0,
#   1336.875,
#   0.12362500000000003],
#  ('sethpwaxman', 0, 'TECHNOLOGY', 'IH'): [613.0,
#   1655.1875,
#   0.03900000000000001],
#  ('sethpwaxman', 0, 'TECHNOLOGY', 'IY'): [501.9375, 2338.0, 0.1211875],
#  ('sethpwaxman', 0, 'DEVELOPMENT', 'IH'): [541.0, 1604.6, 0.0364],
#  ('sethpwaxman', 0, 'DEVELOPMENT', 'EH'): [734.2, 1516.4, 0.0538],
#  ('sethpwaxman', 0, 'DEVELOPMENT', 'AH'): [680.2, 1848.8, 0.0598],
#  ('sethpwaxman', 0, 'CONSEQUENCE', 'AA'): [853.5, 1301.0, 0.14500000000000002],
#  ('sethpwaxman', 0, 'CONSEQUENCE', 'AH'): [745.75, 1701.75, 0.06],
#  ('sethpwaxman', 0, 'ALLEGATIONS', 'AE'): [845.8333333333334,
#   1972.0,
#   0.14316666666666666],
#  ('sethpwaxman', 0, 'ALLEGATIONS', 'AH'): [596.5,
#   1774.1666666666667,
#   0.03833333333333333],
#  ('sethpwaxman', 0, 'ALLEGATIONS', 'EY'): [596.6666666666666,
#   2380.1666666666665,
#   0.09683333333333333],
#  ('sethpwaxman', 0, 'INFRINGEMENT', 'IH'): [605.2941176470588,
#   1842.9411764705883,
#   0.03547058823529412],
#  ('sethpwaxman', 0, 'INFRINGEMENT', 'AH'): [640.1176470588235,
#   1801.5882352941176,
#   0.04835294117647058],
#  ('sethpwaxman', 0, 'ENTITIES', 'EH'): [708.8571428571429,
#   2020.857142857143,
#   0.09142857142857143],
#  ('sethpwaxman', 0, 'ENTITIES', 'AH'): [542.8571428571429,
#   2000.5714285714287,
#   0.04471428571428571],
#  ('sethpwaxman', 0, 'ENTITIES', 'IY'): [449.2857142857143,
#   2365.1428571428573,
#   0.15285714285714283],
#  ('sethpwaxman', 0, 'RISEN', 'IH'): [577.0, 1876.0, 0.06],
#  ('sethpwaxman', 0, 'RISEN', 'AH'): [636.0, 1765.0, 0.07],
#  ('sethpwaxman', 0, 'PROJECTED', 'AH'): [523.0, 1890.0, 0.041],
#  ('sethpwaxman', 0, 'PROJECTED', 'EH'): [765.0, 1774.0, 0.07],
#  ('sethpwaxman', 0, 'INCREASE', 'IH'): [526.8333333333334,
#   2255.5,
#   0.08666666666666667],
#  ('sethpwaxman', 0, 'INCREASE', 'IY'): [470.5,
#   2251.3333333333335,
#   0.09649999999999999],
#  ('sethpwaxman', 0, 'DRAMATICALLY', 'AH'): [586.0, 1531.0, 0.03],
#  ('sethpwaxman', 0, 'DRAMATICALLY', 'AE'): [755.0, 1934.0, 0.081],
#  ('sethpwaxman', 0, 'DRAMATICALLY', 'IH'): [648.0, 1832.0, 0.031],
#  ('sethpwaxman', 0, 'DRAMATICALLY', 'IY'): [521.0, 2293.0, 0.15],
#  ('sethpwaxman', 0, 'VARY', 'EH'): [664.0, 2083.0, 0.11950000000000001],
#  ('sethpwaxman', 0, 'VARY', 'IY'): [506.0, 2179.0, 0.1205],
#  ('sethpwaxman', 0, 'WIDELY', 'AY'): [1093.5, 1311.0, 0.21500000000000002],
#  ('sethpwaxman', 0, 'WIDELY', 'IY'): [510.0, 2316.0, 0.125],
#  ('sethpwaxman', 0, 'MANY', 'EH'): [706.5, 2050.0, 0.085],
#  ('sethpwaxman', 0, 'MANY', 'IY'): [473.5, 2512.0, 0.16899999999999998],
#  ('sethpwaxman', 0, 'INSTANCES', 'IH'): [566.0666666666667,
#   2159.6666666666665,
#   0.07266666666666667],
#  ('sethpwaxman', 0, 'INSTANCES', 'AH'): [515.1333333333333,
#   1860.1333333333334,
#   0.06880000000000001],
#  ('sethpwaxman', 0, 'INADEQUATE', 'IH'): [554.3333333333334,
#   2288.5,
#   0.10683333333333334],
#  ('sethpwaxman', 0, 'INADEQUATE', 'AE'): [775.6, 2090.2, 0.15],
#  ('sethpwaxman', 0, 'INADEQUATE', 'AH'): [656.0, 1719.0, 0.03],
#  ('sethpwaxman', 0, 'INADEQUATE', 'EY'): [701.0, 2339.0, 0.04],
#  ('sethpwaxman', 0, 'PREVENT', 'IH'): [600.7142857142857,
#   1432.0,
#   0.03442857142857143],
#  ('sethpwaxman', 0, 'PREVENT', 'EH'): [742.0,
#   1954.5714285714287,
#   0.14271428571428574],
#  ('sethpwaxman', 0, 'REMEDY', 'EH'): [796.4375,
#   1639.84375,
#   0.061187500000000006],
#  ('sethpwaxman', 0, 'REMEDY', 'AH'): [594.25, 1861.25, 0.03818750000000001],
#  ('sethpwaxman', 0, 'REMEDY', 'IY'): [456.75, 2333.8125, 0.14250000000000004],
#  ('sethpwaxman', 0, 'SECURE', 'IH'): [506.75, 1962.25, 0.048],
#  ('sethpwaxman', 0, 'SECURE', 'UH'): [511.5, 1253.25, 0.153],
#  ('sethpwaxman', 0, 'PROCESS', 'AA'): [966.4,
#   1245.1142857142856,
#   0.07942857142857145],
#  ('sethpwaxman', 0, 'PROCESS', 'EH'): [708.4857142857143,
#   1687.5142857142857,
#   0.106],
#  ('sethpwaxman', 0, 'ABSOLUTELY', 'AE'): [922.0,
#   2015.5714285714287,
#   0.18719047619047618],
#  ('sethpwaxman', 0, 'ABSOLUTELY', 'AH'): [624.1428571428571,
#   1385.3809523809523,
#   0.036857142857142866],
#  ('sethpwaxman', 0, 'ABSOLUTELY', 'UW'): [535.047619047619,
#   1303.142857142857,
#   0.09004761904761904],
#  ('sethpwaxman', 0, 'ABSOLUTELY', 'IY'): [482.85714285714283,
#   2309.714285714286,
#   0.10090476190476191],
#  ('sethpwaxman', 0, 'REASON', 'IY'): [459.5483870967742,
#   2294.548387096774,
#   0.10751612903225807],
#  ('sethpwaxman', 0, 'REASON', 'AH'): [609.8387096774194,
#   1829.0967741935483,
#   0.044677419354838724],
#  ('sethpwaxman', 0, 'NATURE', 'EY'): [639.9333333333333,
#   2254.733333333333,
#   0.15073333333333333],
#  ('sethpwaxman', 0, 'NATURE', 'ER'): [570.0,
#   1320.3333333333333,
#   0.11546666666666668],
#  ('sethpwaxman', 0, 'SOMETHING', 'AH'): [751.0,
#   1348.1224489795918,
#   0.05104081632653062],
#  ('sethpwaxman', 0, 'SOMETHING', 'IH'): [647.4897959183673,
#   2018.3673469387754,
#   0.04510204081632654],
#  ('sethpwaxman', 0, 'I', 'AY'): [1018.5, 1394.0, 0.19974999999999998],
#  ('sethpwaxman', 0, 'PATENT', 'AE'): [989.3818181818182,
#   1918.1272727272728,
#   0.1726],
#  ('sethpwaxman', 0, 'PATENT', 'AH'): [656.3454545454546,
#   1701.7818181818182,
#   0.03132727272727273],
#  ('sethpwaxman', 0, 'LAWYER', 'OY'): [669.25, 1093.5, 0.14950000000000002],
#  ('sethpwaxman', 0, 'LAWYER', 'ER'): [657.0, 1452.25, 0.18775],
#  ('sethpwaxman', 0, 'WASNT', 'AH'): [614.8571428571429,
#   1732.7142857142858,
#   0.03971428571428572],
#  ('sethpwaxman', 0, 'AWARE', 'AH'): [682.6666666666666,
#   1297.3333333333333,
#   0.045000000000000005],
#  ('sethpwaxman', 0, 'AWARE', 'EH'): [622.6666666666666, 1875.0, 0.085],
#  ('sethpwaxman', 0, 'UNTIL', 'AH'): [644.1875, 1644.0625, 0.0549375],
#  ('sethpwaxman', 0, 'UNTIL', 'IH'): [617.5625, 1640.5, 0.04512500000000001],
#  ('sethpwaxman', 0, 'INVOLVED', 'IH'): [582.6363636363636,
#   1858.8181818181818,
#   0.04354545454545455],
#  ('sethpwaxman', 0, 'INVOLVED', 'AA'): [869.5454545454545,
#   1029.5454545454545,
#   0.22754545454545452],
#  ('sethpwaxman', 0, 'INTENTIONAL', 'IH'): [539.3333333333334,
#   2203.5,
#   0.08666666666666667],
#  ('sethpwaxman', 0, 'INTENTIONAL', 'EH'): [730.6666666666666,
#   2083.5,
#   0.07316666666666667],
#  ('sethpwaxman', 0, 'INTENTIONAL', 'AH'): [676.6666666666666,
#   1161.1666666666667,
#   0.03366666666666667],
#  ('sethpwaxman', 0, 'SYSTEM', 'IH'): [556.972972972973,
#   1776.2432432432433,
#   0.040081081081081105],
#  ('sethpwaxman', 0, 'SYSTEM', 'AH'): [633.2432432432432,
#   1562.918918918919,
#   0.050648648648648674],
#  ('sethpwaxman', 0, 'VALIDITY', 'AH'): [515.7777777777778,
#   1980.4444444444443,
#   0.04222222222222222],
#  ('sethpwaxman', 0, 'VALIDITY', 'IH'): [577.3333333333334,
#   1832.888888888889,
#   0.04577777777777777],
#  ('sethpwaxman', 0, 'VALIDITY', 'IY'): [472.8888888888889,
#   2250.8888888888887,
#   0.22088888888888886],
#  ('sethpwaxman', 0, 'CONDUCT', 'AA'): [869.3333333333334,
#   1195.0416666666667,
#   0.14033333333333334],
#  ('sethpwaxman', 0, 'CONDUCT', 'AH'): [650.25, 1686.4375, 0.04881250000000001],
#  ('sethpwaxman', 0, 'WILLFUL', 'IH'): [588.0, 1646.0, 0.039],
#  ('sethpwaxman', 0, 'WILLFUL', 'AH'): [622.0, 1354.0, 0.05],
#  ...}

# %% [markdown]
# - ** Most used words ** We list the words by decreasing frequency, we select the top 20 words (that do not seem to be ideologically relevant) and we arbitrarily pick the first 20 words that may have some ideological content.

# %%
count={}
for e in vowels_final:
    try:
        count[e[1]]+=1
    except KeyError:
        count[e[1]]=1

import operator
sorted_count = sorted(count.items(), key=operator.itemgetter(1),)
sorted(count.items(), key=lambda x: -x[1])
# Out:
# [('THE', 534),
#  ('THAT', 395),
#  ('PARTICULAR', 366),
#  ('SITUATION', 334),
#  ('DIFFERENT', 332),
#  ('FEDERAL', 317),
#  ('A', 315),
#  ('AND', 310),
#  ('NECESSARILY', 306),
#  ('SPECIFICALLY', 306),
#  ('DECISION', 297),
#  ('ABSOLUTELY', 296),
#  ('CONSTITUTIONAL', 295),
#  ('BECAUSE', 294),
#  ('EXAMPLE', 286),
#  ('CIRCUMSTANCES', 285),
#  ('IN', 282),
#  ('TO', 281),
#  ('PARTICULARLY', 276),
#  ('CERTAINLY', 274),
#  ('INDIVIDUAL', 270),
#  ('IMPORTANT', 266),
#  ('EXACTLY', 265),
#  ('INTO', 260),
#  ('DETERMINATION', 260),
#  ('VERY', 256),
#  ('ANY', 254),
#  ('UNDER', 254),
#  ('ARGUMENT', 253),
#  ('JUSTICE', 252),
#  ('IT', 249),
#  ('APPROPRIATE', 247),
#  ('ACTUALLY', 247),
#  ('POSITION', 246),
#  ('ABOUT', 242),
#  ('OTHER', 238),
#  ('SCALIA', 235),
#  ('HYPOTHETICAL', 235),
#  ('GOING', 233),
#  ('ANOTHER', 233),
#  ('ANALYSIS', 233),
#  ('WHETHER', 230),
#  ('BEFORE', 230),
#  ('SPECIFIC', 230),
#  ('ONLY', 225),
#  ('MR', 224),
#  ('QUESTION', 223),
#  ('NECESSARY', 223),
#  ('VIOLATION', 222),
#  ('AUTHORITY', 219),
#  ('IS', 219),
#  ('OPPORTUNITY', 219),
#  ('ISSUE', 214),
#  ('ALSO', 214),
#  ('REALLY', 214),
#  ('OPINION', 212),
#  ('EVERY', 211),
#  ('EVEN', 209),
#  ('EVIDENCE', 209),
#  ('ANYTHING', 208),
#  ('DECIDED', 208),
#  ('APPLICATION', 207),
#  ('GENERAL', 206),
#  ('STATUTORY', 206),
#  ('INTERPRETATION', 206),
#  ('BETWEEN', 205),
#  ('CORRECT', 202),
#  ('HONOR', 201),
#  ('SIGNIFICANT', 201),
#  ('CASES', 200),
#  ('ABILITY', 199),
#  ('BELIEVE', 196),
#  ('DOESNT', 196),
#  ('GOVERNMENT', 195),
#  ('AFTER', 194),
#  ('REASONABLE', 194),
#  ('LEGISLATIVE', 193),
#  ('JURISDICTION', 192),
#  ('LITIGATION', 191),
#  ('WITHIN', 191),
#  ('REASON', 190),
#  ('UH', 188),
#  ('INDIVIDUALS', 188),
#  ('AGAIN', 187),
#  ('NEVER', 186),
#  ('AMENDMENT', 185),
#  ('DECISIONS', 185),
#  ('UNDERSTAND', 185),
#  ('MATTER', 184),
#  ('PROVISION', 184),
#  ('GENERALLY', 182),
#  ('AVAILABLE', 181),
#  ('INTEREST', 181),
#  ('SAYING', 180),
#  ('LIABILITY', 180),
#  ('ESSENTIALLY', 179),
#  ('DIFFERENCE', 179),
#  ('SEPARATE', 178),
#  ('ADDITIONAL', 178),
#  ('IF', 176),
#  ('REQUIRE', 176),
#  ('BEING', 176),
#  ('OUR', 176),
#  ('INDEPENDENT', 174),
#  ('DEFINITION', 173),
#  ('CIRCUIT', 172),
#  ('TWENTY', 172),
#  ('LIMITED', 171),
#  ('AGREE', 171),
#  ('KENNEDY', 171),
#  ('CONSIDERATION', 171),
#  ('INDICATED', 171),
#  ('UNITED', 170),
#  ('STATUTE', 170),
#  ('PRESENTED', 168),
#  ('SIMPLY', 168),
#  ('ANSWER', 166),
#  ('CONGRESS', 166),
#  ('PURPOSES', 166),
#  ('REQUIRES', 166),
#  ('REQUIRED', 166),
#  ('FUNDAMENTAL', 165),
#  ('ALREADY', 165),
#  ('INFORMATION', 165),
#  ('OVER', 164),
#  ('OF', 164),
#  ('DISTINCTION', 164),
#  ('SOMETHING', 162),
#  ('SOMEBODY', 160),
#  ('OBVIOUSLY', 160),
#  ('HOWEVER', 160),
#  ('DEFENDANT', 159),
#  ('WITHOUT', 158),
#  ('EARLIER', 158),
#  ('MAJORITY', 157),
#  ('AGAINST', 156),
#  ('DETERMINE', 156),
#  ('MANY', 156),
#  ('SECOND', 156),
#  ('CANNOT', 156),
#  ('PETITIONERS', 156),
#  ('CONSTITUTION', 153),
#  ('CONSISTENT', 153),
#  ('DISAGREE', 153),
#  ('UNCONSTITUTIONAL', 153),
#  ('HISTORY', 152),
#  ('NUMBER', 152),
#  ('RECOGNIZED', 152),
#  ('EITHER', 152),
#  ('ADDITION', 152),
#  ('RESPECT', 151),
#  ('QUESTIONS', 150),
#  ('SECTION', 150),
#  ('DISTRICT', 150),
#  ('CLEARLY', 150),
#  ('SEVEN', 150),
#  ('ENTIRELY', 150),
#  ('PETITIONER', 149),
#  ('LEGISLATURE', 149),
#  ('DIRECTLY', 149),
#  ('POSSIBILITY', 149),
#  ('CALIFORNIA', 149),
#  ('VERSUS', 148),
#  ('ACTION', 148),
#  ('PEOPLE', 148),
#  ('ACTIVITY', 147),
#  ('GINSBURG', 146),
#  ('DISCRETION', 145),
#  ('SIMILAR', 145),
#  ('TALKING', 144),
#  ('ISSUES', 144),
#  ('REGULATIONS', 144),
#  ('SEVENTY', 144),
#  ('CRIMINAL', 144),
#  ('AREA', 143),
#  ('POSSIBLE', 143),
#  ('APPENDIX', 143),
#  ('UNDERSTANDING', 143),
#  ('ENTITLED', 142),
#  ('BASIS', 142),
#  ('REQUIREMENT', 142),
#  ('PETITION', 142),
#  ('PROBLEM', 140),
#  ('GIVEN', 140),
#  ('NOTHING', 140),
#  ('TESTIMONY', 139),
#  ('PRESENT', 139),
#  ('AS', 138),
#  ('RESULT', 138),
#  ('RECORD', 138),
#  ('DIDNT', 138),
#  ('APPLY', 138),
#  ('POLICY', 137),
#  ('NINETEEN', 136),
#  ('EFFECT', 136),
#  ('DIFFICULT', 136),
#  ('PROCEEDING', 136),
#  ('SUBJECT', 135),
#  ('INCLUDING', 135),
#  ('THEORY', 135),
#  ('PROVISIONS', 135),
#  ('ULTIMATELY', 135),
#  ('CONTEXT', 134),
#  ('SEVERAL', 134),
#  ('ITSELF', 134),
#  ('ITS', 133),
#  ('OTHERWISE', 133),
#  ('JURISDICTIONAL', 133),
#  ('WANTED', 132),
#  ('ACTIVITIES', 132),
#  ('DETERMINING', 132),
#  ('MAKING', 132),
#  ('PROPOSITION', 132),
#  ('INTERESTS', 132),
#  ('FIFTY', 131),
#  ('RELATIONSHIP', 131),
#  ('ESTABLISHED', 131),
#  ('ABLE', 130),
#  ('CONSTITUTIONALLY', 129),
#  ('I', 129),
#  ('ALTERNATIVE', 129),
#  ('ADOPTED', 129),
#  ('REGULATION', 129),
#  ('INTENDED', 129),
#  ('JUDGMENT', 128),
#  ('STANDARD', 128),
#  ('PROCESS', 128),
#  ('CERTAIN', 128),
#  ('ORDER', 128),
#  ('PROBABLY', 128),
#  ('HAVING', 128),
#  ('PERSON', 128),
#  ('UNDERLYING', 128),
#  ('IDEA', 128),
#  ('GONNA', 128),
#  ('HUNDRED', 127),
#  ('RESPECTFULLY', 127),
#  ('OBLIGATION', 127),
#  ('PROCEDURAL', 127),
#  ('UNUSUAL', 127),
#  ('FURTHER', 126),
#  ('UNLESS', 126),
#  ('REMEDY', 125),
#  ('ADDRESS', 124),
#  ('PROVIDED', 124),
#  ('WHATEVER', 124),
#  ('SUFFICIENT', 124),
#  ('DOING', 124),
#  ('INTERPRETED', 124),
#  ('IDENTIFIED', 124),
#  ('ELEMENT', 123),
#  ('ISNT', 123),
#  ('WASNT', 123),
#  ('DIRECT', 123),
#  ('RESERVE', 123),
#  ('CONSIDER', 123),
#  ('ADMINISTRATIVE', 123),
#  ('TAKEN', 122),
#  ('PERIOD', 122),
#  ('JUDICIAL', 122),
#  ('REASONS', 122),
#  ('EIGHTY', 122),
#  ('RATHER', 122),
#  ('THIRTY', 120),
#  ('APPEALS', 120),
#  ('LANGUAGE', 120),
#  ('UPON', 120),
#  ('SORRY', 120),
#  ('CONTRARY', 119),
#  ('DISCRIMINATION', 119),
#  ('GOVERNMENTS', 119),
#  ('RESPONSIBILITY', 119),
#  ('EVER', 118),
#  ('PURPOSE', 118),
#  ('RELEVANT', 118),
#  ('DETERMINED', 117),
#  ('IMMEDIATELY', 117),
#  ('WE', 117),
#  ('LIMITATIONS', 117),
#  ('ENFORCEMENT', 116),
#  ('VIOLATED', 116),
#  ('PROCEDURE', 116),
#  ('PROCEEDINGS', 116),
#  ('ALWAYS', 115),
#  ('CONSIDERED', 115),
#  ('ENTIRE', 115),
#  ('EXCEPTION', 115),
#  ('ORIGINAL', 115),
#  ('CONSEQUENCES', 115),
#  ('PARTIES', 114),
#  ('REPEATEDLY', 114),
#  ('VIOLATIONS', 114),
#  ('REVIEW', 114),
#  ('APPLIED', 114),
#  ('ORDINARY', 114),
#  ('ENOUGH', 114),
#  ('ALLOW', 114),
#  ('ELEMENTS', 114),
#  ('DEFENDANTS', 113),
#  ('SUGGEST', 112),
#  ('WOULDNT', 112),
#  ('BREYER', 112),
#  ('BENEFIT', 112),
#  ('ASSUMING', 112),
#  ('PRINCIPLE', 112),
#  ('FORTY', 112),
#  ('ACTUAL', 111),
#  ('LIMITATION', 111),
#  ('UNTIL', 110),
#  ('EXERCISE', 110),
#  ('CONCLUSION', 110),
#  ('LOWER', 110),
#  ('LITTLE', 110),
#  ('COMPLETELY', 110),
#  ('INDICATION', 110),
#  ('INCONSISTENT', 110),
#  ('PROTECTION', 110),
#  ('EVIDENTIARY', 110),
#  ('THOUSAND', 110),
#  ('FUNDAMENTALLY', 110),
#  ('SITUATIONS', 109),
#  ('PRINCIPLES', 109),
#  ('PRECISELY', 109),
#  ('EXTRAORDINARY', 109),
#  ('APPLYING', 109),
#  ('FOLLOWING', 109),
#  ('VARIETY', 109),
#  ('CREATED', 108),
#  ('PERHAPS', 108),
#  ('CIRCUMSTANCE', 108),
#  ('COUNSEL', 108),
#  ('BUT', 108),
#  ('REQUIREMENTS', 108),
#  ('REJECTED', 108),
#  ('REGULATORY', 108),
#  ('ARGUMENTS', 107),
#  ('JURISPRUDENCE', 107),
#  ('RESPONSE', 107),
#  ('THIS', 107),
#  ('CONDUCT', 106),
#  ('DECIDING', 106),
#  ('YOU', 106),
#  ('ADDRESSED', 106),
#  ('DOCTRINE', 106),
#  ('PERMISSIBLE', 106),
#  ('LEGITIMATE', 105),
#  ('DURING', 105),
#  ('RESPONDENTS', 105),
#  ('SYSTEM', 104),
#  ('NATURE', 104),
#  ('PUBLIC', 104),
#  ('GETTING', 104),
#  ('BEYOND', 104),
#  ('CONTINUE', 104),
#  ('CHARACTERIZATION', 104),
#  ('POLITICAL', 104),
#  ('BASICALLY', 103),
#  ('PROPERLY', 103),
#  ('EVERYBODY', 103),
#  ('PROSECUTION', 103),
#  ('LOOKING', 102),
#  ('INQUIRY', 102),
#  ('SUGGESTED', 102),
#  ('TRADITIONAL', 102),
#  ('PURSUANT', 102),
#  ('EVERYTHING', 102),
#  ('ELEVEN', 102),
#  ('ECONOMIC', 102),
#  ('DOCUMENT', 102),
#  ('INVESTIGATION', 102),
#  ('ENACTED', 101),
#  ('SUBSTANTIAL', 101),
#  ('TODAY', 101),
#  ('PROSECUTOR', 101),
#  ('BELOW', 100),
#  ('SUBMIT', 100),
#  ('REASONABLY', 100),
#  ('RESPONDENT', 100),
#  ('STEVENS', 100),
#  ('INDEED', 100),
#  ('AMERICAN', 100),
#  ('SUGGESTING', 99),
#  ('OCONNOR', 99),
#  ('INCLUDED', 99),
#  ('ESTABLISH', 99),
#  ('PERFECTLY', 99),
#  ('DISCRETIONARY', 99),
#  ('TOGETHER', 99),
#  ('CATEGORY', 99),
#  ('DIFFERENTLY', 99),
#  ('AMICUS', 98),
#  ('OR', 98),
#  ('ALTHOUGH', 98),
#  ('STATUTES', 98),
#  ('ASKING', 98),
#  ('EMPLOYEE', 98),
#  ('CIRCUITS', 98),
#  ('ARGUING', 97),
#  ('DISCUSSION', 97),
#  ('IDENTIFY', 97),
#  ('ADMINISTRATION', 97),
#  ('SOTOMAYOR', 97),
#  ('INTENT', 96),
#  ('SOLICITOR', 96),
#  ('PROTECTED', 96),
#  ('SIXTY', 96),
#  ('POINTED', 96),
#  ('JURY', 96),
#  ('HAPPEN', 96),
#  ('UNDERSTOOD', 96),
#  ('INSTEAD', 96),
#  ('OPERATION', 96),
#  ('LEGISLATION', 95),
#  ('THATS', 95),
#  ('ADEQUATE', 95),
#  ('APPELLATE', 95),
#  ('THERE', 95),
#  ('PRESUMABLY', 95),
#  ('REMEMBER', 95),
#  ('THEY', 95),
#  ('UNREASONABLE', 95),
#  ('POWER', 94),
#  ('EXTENT', 94),
#  ('AWARE', 94),
#  ('PROVIDE', 94),
#  ('ESPECIALLY', 94),
#  ('CONSIDERING', 94),
#  ('INTERESTING', 94),
#  ('DISCOVERY', 94),
#  ('CONTINUING', 94),
#  ('MEANING', 93),
#  ('FINALLY', 93),
#  ('PRIMARY', 93),
#  ('ALLEGATION', 93),
#  ('DISCRIMINATORY', 93),
#  ('EFFECTIVELY', 93),
#  ('SIGNIFICANCE', 93),
#  ('CONSIDERATIONS', 93),
#  ('INVOLVED', 92),
#  ('DEALING', 92),
#  ('LEGAL', 92),
#  ('APPEAL', 92),
#  ('DAMAGES', 92),
#  ('OBLIGATIONS', 92),
#  ('STATEMENT', 92),
#  ('VIOLATE', 92),
#  ('AWAY', 92),
#  ('WHAT', 92),
#  ('CONCERNS', 92),
#  ('INJURY', 92),
#  ('COMMISSION', 92),
#  ('CONSTITUTIONALITY', 91),
#  ('NINETY', 91),
#  ('ANYBODY', 91),
#  ('SUPREME', 91),
#  ('CRITERIA', 91),
#  ('MANDATORY', 91),
#  ('CERTIORARI', 91),
#  ('PROPERTY', 90),
#  ('VIRTUALLY', 90),
#  ('SUBSTANTIVE', 90),
#  ('TAKING', 90),
#  ('SINGLE', 90),
#  ('PRELIMINARY', 90),
#  ('CONGRESSIONAL', 90),
#  ('COMMON', 90),
#  ('COMMITTED', 90),
#  ('CONVICTION', 90),
#  ('PROHIBITED', 89),
#  ('REBUTTAL', 89),
#  ('REFERENCE', 89),
#  ('AGREEMENT', 89),
#  ('SOMEONE', 88),
#  ('SUFFICIENTLY', 88),
#  ('FACTUAL', 88),
#  ('LEVEL', 88),
#  ('CRITICAL', 88),
#  ('PREVIOUSLY', 88),
#  ('AMENDED', 88),
#  ('PARTY', 88),
#  ('HAPPENED', 88),
#  ('DEPENDING', 88),
#  ('LITERALLY', 88),
#  ('REMAINDER', 88),
#  ('APPROXIMATELY', 88),
#  ('PRACTICAL', 87),
#  ('SERIOUS', 87),
#  ('REQUIRING', 87),
#  ('RELATED', 87),
#  ('UNDISPUTED', 87),
#  ('CORRECTLY', 86),
#  ('USING', 86),
#  ('ALLEGATIONS', 86),
#  ('THEREFORE', 86),
#  ('ACCEPTED', 86),
#  ('FINANCIAL', 86),
#  ('APPLIES', 86),
#  ('COMPLAINT', 86),
#  ('CONTROL', 86),
#  ('ATTORNEY', 86),
#  ('PERCENT', 86),
#  ('INTERNATIONAL', 86),
#  ('REFERRING', 86),
#  ('SENTENCING', 86),
#  ('AFFIRMATIVE', 86),
#  ('IMMUNITY', 85),
#  ('POTENTIALLY', 85),
#  ('INVOLVING', 85),
#  ('IDENTICAL', 85),
#  ('SUBMITTED', 85),
#  ('HABEAS', 85),
#  ('REMEDIES', 84),
#  ('RELIEF', 84),
#  ('COUNTRY', 84),
#  ('HEARING', 84),
#  ('PROVIDING', 84),
#  ('DECIDE', 84),
#  ('DISPUTE', 84),
#  ('CONCERN', 84),
#  ('COULDNT', 84),
#  ('SUGGESTION', 84),
#  ('SECURITY', 84),
#  ('EXAMINATION', 83),
#  ('OFFICER', 83),
#  ('AGENCY', 83),
#  ('EMPLOYEES', 83),
#  ('CATEGORIES', 83),
#  ('ALITO', 83),
#  ('BUSINESS', 82),
#  ('PROBLEMS', 82),
#  ('INSTANCE', 82),
#  ('ALLOWED', 82),
#  ('SUPPORT', 82),
#  ('COMPLICATED', 82),
#  ('INDICATE', 82),
#  ('INCLUDE', 82),
#  ('MOTION', 82),
#  ('EXCEPT', 82),
#  ('SIGNIFICANTLY', 82),
#  ('AMOUNT', 82),
#  ('AUTOMATICALLY', 82),
#  ('ARBITRARY', 82),
#  ('DOCUMENTS', 82),
#  ('PROTECT', 81),
#  ('ASSOCIATION', 81),
#  ('SUMMARY', 81),
#  ('PRECEDENT', 81),
#  ('VARIOUS', 81),
#  ('DIRECTED', 81),
#  ('ACCEPTABLE', 81),
#  ('EXPRESSLY', 81),
#  ('PRESUMPTION', 81),
#  ('MAYBE', 80),
#  ('STATED', 80),
#  ('REGARDLESS', 80),
#  ('CREATE', 80),
#  ('PROVIDES', 80),
#  ('ACTIONS', 80),
#  ('RESOLUTION', 80),
#  ('OPINIONS', 80),
#  ('WHATSOEVER', 80),
#  ('BEGINNING', 80),
#  ('APPLICABLE', 80),
#  ('BETTER', 80),
#  ('ANYONE', 80),
#  ('NOTICE', 80),
#  ('PRACTICE', 80),
#  ('IMPOSSIBLE', 80),
#  ('ARTICULATED', 79),
#  ('PREVENT', 79),
#  ('INCORPORATED', 79),
#  ('AREAS', 79),
#  ('READING', 79),
#  ('MATERIAL', 79),
#  ('YOUR', 79),
#  ('AT', 78),
#  ('FACTORS', 78),
#  ('PROPER', 78),
#  ('RATIONALE', 78),
#  ('EXCUSE', 78),
#  ('SERVICES', 78),
#  ('FOCUS', 78),
#  ('ARGUE', 78),
#  ('PROCEED', 78),
#  ('POTENTIAL', 78),
#  ('PERSONAL', 78),
#  ('APPROACH', 78),
#  ('OFFICERS', 78),
#  ('LAWYERS', 78),
#  ('JUSTIFICATION', 78),
#  ('PENALTY', 78),
#  ('BENEFITS', 77),
#  ('INAPPROPRIATE', 77),
#  ('ON', 77),
#  ('SEVENTEEN', 77),
#  ('SOCIETY', 77),
#  ('ASSUME', 76),
#  ('OBJECTIVE', 76),
#  ('EIGHTEEN', 76),
#  ('LATER', 76),
#  ('RECOGNIZE', 76),
#  ('FORWARD', 76),
#  ('LIKELY', 76),
#  ('BURDEN', 76),
#  ('AROUND', 76),
#  ('COMPANY', 76),
#  ('MERELY', 76),
#  ('EXERCISING', 76),
#  ('WOULD', 76),
#  ('STANDING', 76),
#  ('ORGANIZATION', 76),
#  ('DOLLARS', 76),
#  ('EMPLOYER', 76),
#  ('IRRELEVANT', 76),
#  ('EXPECTATION', 76),
#  ('EXPERIENCE', 76),
#  ('DECLARATION', 76),
#  ('CONCLUDED', 75),
#  ('UNANIMOUSLY', 75),
#  ('SUPPORTED', 75),
#  ('INTERPRETING', 75),
#  ('EXPLICITLY', 75),
#  ('ALLOWING', 75),
#  ('PROHIBITION', 75),
#  ('CONSTRUCTION', 75),
#  ('DETERMINATIONS', 75),
#  ('REPRESENTATIVE', 75),
#  ('ADJUDICATION', 75),
#  ('ORDINARILY', 74),
#  ('EXISTED', 74),
#  ('SENTENCE', 74),
#  ('MERITS', 74),
#  ('SATISFY', 74),
#  ('IMAGINE', 74),
#  ('ACCEPT', 74),
#  ('REGARD', 74),
#  ('FOR', 74),
#  ('FOLLOW', 74),
#  ('BALANCE', 74),
#  ('RESPONSIBLE', 74),
#  ('CONCERNED', 74),
#  ('OCCURRED', 74),
#  ('ARGUED', 74),
#  ('SOUTER', 74),
#  ('WANNA', 74),
#  ('GIVING', 74),
#  ('EXAMPLES', 74),
#  ('AMBIGUITY', 74),
#  ('JURISDICTIONS', 74),
#  ('PROSECUTORS', 74),
#  ('POSSIBLY', 73),
#  ('COLLATERAL', 73),
#  ('NO', 73),
#  ('WITH', 73),
#  ('EXECUTIVE', 73),
#  ('REPRESENTATION', 73),
#  ('INDISTINGUISHABLE', 73),
#  ('STANDARDS', 72),
#  ('ARTICLE', 72),
#  ('DIFFERENCES', 72),
#  ('MINIMUM', 72),
#  ('ARE', 72),
#  ('REFERRED', 72),
#  ('PLAINTIFFS', 72),
#  ('NARROW', 72),
#  ('MONEY', 72),
#  ('CIVIL', 72),
#  ('PRINCIPAL', 72),
#  ('HAVENT', 72),
#  ('COMPLIANCE', 72),
#  ('COVERED', 72),
#  ('OPERATING', 72),
#  ('DIFFICULTY', 72),
#  ('INDICATES', 72),
#  ('ACCORDING', 72),
#  ('GOVERNMENTAL', 72),
#  ('FEDERALISM', 72),
#  ('CATEGORICAL', 71),
#  ('HOLDING', 71),
#  ('SATISFIED', 71),
#  ('APPARENTLY', 71),
#  ('PRIOR', 71),
#  ('FINALITY', 71),
#  ('THEMSELVES', 71),
#  ('LITIGATED', 71),
#  ('ATTENTION', 71),
#  ('INDEPENDENTLY', 71),
#  ('REPRESENTED', 71),
#  ('CHALLENGE', 70),
#  ('GRANTED', 70),
#  ('COMPENSATION', 70),
#  ('ALMOST', 70),
#  ('OKAY', 70),
#  ('COUPLE', 70),
#  ('INITIAL', 70),
#  ('FACTOR', 70),
#  ('JUDGES', 70),
#  ('AGO', 70),
#  ('MISUNDERSTOOD', 70),
#  ('EXPLANATION', 70),
#  ('PRESIDENT', 70),
#  ('INTERESTED', 70),
#  ('CORPORATION', 69),
#  ('UNFORTUNATELY', 69),
#  ('ABSOLUTE', 69),
#  ('CONNECTION', 69),
#  ('PERMITTED', 69),
#  ('BALANCING', 69),
#  ('REPRESENT', 69),
#  ('EQUIVALENT', 69),
#  ('OTHERS', 68),
#  ('DIRECTION', 68),
#  ('SCENARIO', 68),
#  ('MECHANISM', 68),
#  ('MENTIONED', 68),
#  ('ARGUABLY', 68),
#  ('INTERPRET', 68),
#  ('REGULATED', 68),
#  ('WAS', 68),
#  ('FIFTEEN', 68),
#  ('THINK', 68),
#  ('EXTENDED', 68),
#  ('ANYWHERE', 68),
#  ('FUTURE', 68),
#  ('VOLUNTARY', 68),
#  ('WITNESSES', 68),
#  ('IDENTIFYING', 68),
#  ('DEFERENCE', 67),
#  ('PROCEDURES', 67),
#  ('INADEQUATE', 67),
#  ('EXISTENCE', 67),
#  ('LIABLE', 67),
#  ('SUBSTANTIALLY', 67),
#  ('RESOURCES', 67),
#  ('NATURAL', 67),
#  ('AMBIGUOUS', 67),
#  ('CONTROVERSY', 67),
#  ('DEFINITELY', 67),
#  ('COMMUNICATION', 67),
#  ('NOTWITHSTANDING', 67),
#  ('INJUNCTION', 66),
#  ('NEEDED', 66),
#  ('SPECIAL', 66),
#  ('RESPOND', 66),
#  ('LAWYER', 66),
#  ('OFTEN', 66),
#  ('DEPARTMENT', 66),
#  ('DISCUSSED', 66),
#  ('RECEIVE', 66),
#  ('INCORRECT', 66),
#  ('SUBSEQUENT', 66),
#  ('ASSERTED', 66),
#  ('ATTEMPTED', 66),
#  ('PHYSICAL', 66),
#  ('REASONABLENESS', 66),
#  ('IDENTIFICATION', 66),
#  ('EXCLUDED', 65),
#  ('CAPACITY', 65),
#  ('TOTALLY', 65),
#  ('HISTORICAL', 65),
#  ('YES', 65),
#  ('RULING', 65),
#  ('JUDICIARY', 65),
#  ('SECONDLY', 65),
#  ('DISCUSSING', 65),
#  ('DISTINGUISH', 65),
#  ('OBJECTION', 65),
#  ('AMENDMENTS', 65),
#  ('VIOLATING', 65),
#  ('SEPARATELY', 65),
#  ('DETERMINATIVE', 65),
#  ('WASHINGTON', 65),
#  ('VALUE', 64),
#  ('ACCESS', 64),
#  ('VALIDITY', 64),
#  ('HAPPENS', 64),
#  ('PARTICIPATE', 64),
#  ('REMAND', 64),
#  ('CITED', 64),
#  ('IMPOSES', 64),
#  ('PLAINTIFF', 64),
#  ('AMONG', 64),
#  ('DISMISS', 64),
#  ('THIRTEEN', 64),
#  ('MATTERS', 64),
#  ('WORKING', 64),
#  ('CITIZENS', 64),
#  ('ELIGIBLE', 64),
#  ('MATERIALS', 64),
#  ('AGREED', 64),
#  ('RETURN', 64),
#  ('APPLICATIONS', 64),
#  ('CONVICTED', 64),
#  ('CORPORATIONS', 64),
#  ('RETALIATION', 64),
#  ('DETERMINES', 63),
#  ('TRADITIONALLY', 63),
#  ('ELIMINATE', 63),
#  ('EDUCATION', 63),
#  ('BENEFICIARY', 63),
#  ('REMANDED', 63),
#  ('AFFECTED', 63),
#  ('DENIAL', 63),
#  ('MULTIPLE', 63),
#  ('FIDUCIARY', 63),
#  ('ASSERTING', 63),
#  ('REMEDIAL', 63),
#  ('MITIGATING', 63),
#  ('ENTITY', 62),
#  ('ATTEMPT', 62),
#  ('PERSONS', 62),
#  ('DEPENDS', 62),
#  ('SUGGESTS', 62),
#  ('WRITTEN', 62),
#  ('RESOLVED', 62),
#  ('PRIMARILY', 62),
#  ('FINDING', 62),
#  ('HASNT', 62),
#  ('LIMIT', 62),
#  ('AFFIDAVIT', 62),
#  ('CONFLICT', 62),
#  ('ALLEGED', 62),
#  ('ALLOWS', 62),
#  ('REMAINING', 62),
#  ('NOBODY', 62),
#  ('TYPICALLY', 62),
#  ('THEORETICALLY', 62),
#  ('PROHIBITING', 62),
#  ('IMPLICATION', 62),
#  ('NATIONAL', 61),
#  ('CONDITION', 61),
#  ('GENERALS', 61),
#  ('USUALLY', 61),
#  ('CERTIFICATION', 61),
#  ('DISPOSITION', 61),
#  ('AUTHORITIES', 61),
#  ('REQUEST', 61),
#  ('ORIGINALLY', 61),
#  ('CHALLENGING', 61),
#  ('COMMUNICATIONS', 61),
#  ('PRIVATE', 60),
#  ('ANALOGOUS', 60),
#  ('DEFINED', 60),
#  ('SHOWING', 60),
#  ('EXIST', 60),
#  ('ADDRESSING', 60),
#  ('REFER', 60),
#  ('BROADER', 60),
#  ('EXISTS', 60),
#  ('IMPACT', 60),
#  ('ALONE', 60),
#  ('OPPOSED', 60),
#  ('ISSUED', 60),
#  ('DIVERSITY', 60),
#  ('SERVICE', 60),
#  ('ACTING', 60),
#  ('FUNCTION', 60),
#  ('EASILY', 60),
#  ('RELATIVELY', 60),
#  ('CONDITIONS', 60),
#  ('OPERATE', 60),
#  ('ULTIMATE', 60),
#  ('CONCERNING', 60),
#  ('EVERYONE', 60),
#  ('ERRONEOUS', 60),
#  ('ADDED', 60),
#  ('DEVELOPED', 60),
#  ('PUTTING', 60),
#  ('FOCUSING', 60),
#  ('PARTICIPATION', 60),
#  ('VOLUNTARILY', 60),
#  ('COMPANIES', 60),
#  ('FOOTNOTE', 60),
#  ('CONTENTION', 60),
#  ('EXISTING', 60),
#  ('COMPETITION', 60),
#  ('DENYING', 60),
#  ('DESCRIPTION', 60),
#  ('ENGAGED', 60),
#  ('TEXAS', 60),
#  ('SECURITIES', 60),
#  ('ERROR', 60),
#  ('PARTICIPATING', 60),
#  ('RELYING', 60),
#  ('ASSOCIATED', 60),
#  ('PROSECUTORIAL', 60),
#  ('OPENING', 60),
#  ('ADVISORY', 60),
#  ('FELONY', 60),
#  ('RECOGNITION', 60),
#  ('VIOLATES', 60),
#  ('MINORITY', 60),
#  ('ATTRIBUTABLE', 60),
#  ('DISCLOSURE', 59),
#  ('INFERENCE', 59),
#  ('REVERSAL', 59),
#  ('DISPOSITIVE', 59),
#  ('TESTIFIED', 59),
#  ('RELIED', 59),
#  ('PARAGRAPH', 59),
#  ('EXCEPTIONS', 59),
#  ('EMPLOYMENT', 59),
#  ('INSTRUCTION', 59),
#  ('RESULTS', 59),
#  ('METHODOLOGY', 59),
#  ('COLORADO', 59),
#  ('REALITY', 59),
#  ('DELIBERATELY', 58),
#  ('MARKET', 58),
#  ('EXCLUSIVE', 58),
#  ('CONCEDE', 58),
#  ('CONCEDED', 58),
#  ('SECRETARY', 58),
#  ('IMPOSE', 58),
#  ('FOCUSED', 58),
#  ('DEPOSITION', 58),
#  ('OPEN', 58),
#  ('MOMENT', 58),
#  ('RECEIVED', 58),
#  ('ENTERED', 58),
#  ('DEFENSE', 58),
#  ('TREATED', 58),
#  ('OPERATIONS', 58),
#  ('INVOLVES', 58),
#  ('EMPLOYERS', 58),
#  ('ENFORCE', 58),
#  ('POLICIES', 58),
#  ('ENFORCEABLE', 58),
#  ('THROUGHOUT', 58),
#  ('MANAGEMENT', 58),
#  ('USES', 58),
#  ('ACKNOWLEDGE', 58),
#  ('WHENEVER', 58),
#  ('PROFESSIONAL', 58),
#  ('CONSISTENTLY', 58),
#  ('MITIGATION', 58),
#  ('RECENTLY', 57),
#  ('ESSENTIAL', 57),
#  ('REPORT', 57),
#  ('OPPOSITE', 57),
#  ('CATEGORICALLY', 57),
#  ('ONGOING', 57),
#  ('ALTERNATIVES', 57),
#  ('PROBABLE', 57),
#  ('HAPPENING', 57),
#  ('REVERSED', 57),
#  ('CONTROLLING', 57),
#  ('ENTITLEMENT', 57),
#  ('OFFICIAL', 57),
#  ('DISTRIBUTION', 57),
#  ('MISREPRESENTATION', 57),
#  ('INSTRUCTIONS', 57),
#  ('INITIATED', 57),
#  ('CUSTODY', 57),
#  ('CAPITAL', 57),
#  ('ADJUDICATED', 57),
#  ('DESIGNED', 56),
#  ('BECOME', 56),
#  ('UNIFORMITY', 56),
#  ('COMING', 56),
#  ('BASIC', 56),
#  ('OPERATIVE', 56),
#  ('LONGER', 56),
#  ('OCCUR', 56),
#  ('ALONG', 56),
#  ('EQUITABLE', 56),
#  ('RELATIONS', 56),
#  ('LEGISLATURES', 56),
#  ('AFFECT', 56),
#  ('INDIVIDUALIZED', 56),
#  ('MANNER', 56),
#  ('APPEARS', 56),
#  ('PAGES', 56),
#  ('ANALOGY', 56),
#  ('ACCURATE', 56),
#  ('CALIFORNIAS', 56),
#  ('CREATES', 56),
#  ('COMPELLING', 56),
#  ('SCRUTINY', 56),
#  ('OFFENSE', 56),
#  ('OFFICE', 56),
#  ('STATEMENTS', 56),
#  ('CREATING', 56),
#  ('UNANIMOUS', 56),
#  ('SCALIAS', 56),
#  ('DEMOCRATIC', 56),
#  ('WOULDVE', 56),
#  ('HISTORICALLY', 56),
#  ('MUNICIPALITIES', 56),
#  ('ARISING', 55),
#  ('FREQUENTLY', 55),
#  ('OUTSIDE', 55),
#  ('FACILITY', 55),
#  ('INTERPRETATIONS', 55),
#  ('ADEQUATELY', 55),
#  ('CONTRACT', 55),
#  ('PENNSYLVANIA', 55),
#  ('CONSIDERABLE', 55),
#  ('QUALIFIED', 55),
#  ('IMPORTANTLY', 55),
#  ...]

# %%
non_charged=['SITUATION','BECAUSE','EXAMPLE','PARTICULAR','DIFFERENT','CERTAINLY',
             'IMPORTANT','INTO','ABSOLUTELY','ABOUT','UNDER','SPECIFICALLY','WHETHER',
            'OTHER','EXACTLY']
charged=['FEDERAL','SCALIA','OPPORTUNITY','STATUTORY','HONOR','MR','LEGISLATIVE',
         'CONSTITUTIONAL','KENNEDY','AUTHORITY','GINSBURG','LEGISLATURE','PEOPLE',
        'POLICY','CONGRESS','GOVERNMENT','AMENDMENT','CONSTITUTION','ECONOMIC',
         'CALIFORNIA']

# %% [markdown]
# #### We split the speakers into a training group and a test group

# %%
# Out:
# {('aaron', 'panner'): '0.0',
#  ('alan', 'freedman'): '0.0',
#  ('alan', 'gura'): '1.0',
#  ('alan', 'morrison'): '0.0',
#  ('alan', 'untereiner'): '0.0',
#  ('alexander', 'reichert'): '0.0',
#  ('allison', 'zieve'): '0.0',
#  ('amanda', 'leiter'): '0.0',
#  ('amy', 'howe'): '0.007246376811594203',
#  ('amy', 'zapp'): '1.0',
#  ('andrew', 'frey'): '0.0',
#  ('andrew', 'pincus'): '0.0',
#  ('andrew', 'rossman'): '0.0',
#  ('anita', 'alvarez'): '1.0',
#  ('ann', 'oconnell'): '0.0',
#  ('anthony', 'yang'): '0.0',
#  ('arthur', 'bryant'): '0.0',
#  ('arthur', 'fergenson'): '1.0',
#  ('barbara', 'mcdowell'): '0.0',
#  ('barry', 'barnett'): '0.003323262839879154',
#  ('barry', 'ostrager'): '0.0',
#  ('beau', 'brindley'): '0.0',
#  ('bert', 'deixler'): '0.0',
#  ('bert', 'rein'): '0.6153846153846154',
#  ('beth', 'brinkmann'): '0.0',
#  ('bradley', 'phillips'): '0.0',
#  ('brian', 'barov'): '0.0',
#  ('brian', 'lauten'): '0.0',
#  ('brian', 'shiffrin'): '0.0',
#  ('brian', 'wolfman'): '0.0',
#  ('bruce', 'ennis'): '1.0',
#  ('bruce', 'smith'): '0.20833333333333334',
#  ('bruce', 'terris'): '0.0',
#  ('c', 'trower'): '0.875',
#  ('caitlin', 'halligan'): '0.0',
#  ('candace', 'cain'): '0.0',
#  ('carolyn', 'kubitschek'): '0.0',
#  ('carter', 'phillips'): '0.0',
#  ('catherine', 'smith'): '0.09401709401709402',
#  ('catherine', 'stetson'): '0.0',
#  ('chad', 'readler'): '1.0',
#  ('charles', 'condon'): '1.0',
#  ('charles', 'cooper'): '0.7252567693744165',
#  ('charles', 'rothfeld'): '0.0',
#  ('charles', 'sevilla'): '0.0',
#  ('charles', 'sims'): '0.0',
#  ('charles', 'wright'): '0.4827586206896552',
#  ('christopher', 'browning'): '0.0',
#  ('christopher', 'burke'): '0.0',
#  ('christopher', 'landau'): '1.0',
#  ('christopher', 'meade'): '0.037286724927174365',
#  ('christopher', 'paolella'): '1.0',
#  ('christopher', 'wray'): '1.0',
#  ('clay', 'smith'): '0.30319148936170215',
#  ('clifford', 'sloan'): '0.0',
#  ('clifton', 'hutchinson'): '1.0',
#  ('clint', 'bolick'): '1.0',
#  ('collyn', 'peddie'): '0.044642857142857144',
#  ('connie', 'lensing'): '0.0',
#  ('corbett', 'gordon'): '0.0',
#  ('corinne', 'beckwith'): '0.0',
#  ('courtland', 'reichman'): '0.0',
#  ('craig', 'goldblatt'): '0.0',
#  ('craig', 'jones'): '0.0',
#  ('craig', 'stewart'): '0.11457431215500621',
#  ('curtis', 'gannon'): '1.0',
#  ('dan', 'johnson'): '0.5',
#  ('daniel', 'bromberg'): '0.08250825082508251',
#  ('daniel', 'ortiz'): '0.7004124065641378',
#  ('daniel', 'small'): '0.0',
#  ('danielle', 'spinelli'): '0.0',
#  ('daryl', 'joseffer'): '1.0',
#  ('david', 'bederman'): '0.0',
#  ('david', 'boies'): '0.3468338725085468',
#  ('david', 'bowker'): '0.0',
#  ('david', 'burman'): '0.0',
#  ('david', 'frederick'): '0.0',
#  ('david', 'friedman'): '0.4699356283782079',
#  ('david', 'furlow'): '0.8914565826330532',
#  ('david', 'kaplan'): '0.0461236316271587',
#  ('david', 'lane'): '0.4857142857142857',
#  ('david', 'lawrence'): '0.16129032258064516',
#  ('david', 'lew'): '0.0',
#  ('david', 'mills'): '0.0',
#  ('david', 'moran'): '0.047573739295908656',
#  ('david', 'neff'): '0.0',
#  ('david', 'oneil'): '0.0',
#  ('david', 'porter'): '0.6047008547008548',
#  ('david', 'robbins'): '0.01825117263784198',
#  ('david', 'rose'): '0.0',
#  ('david', 'salmons'): '1.0',
#  ('david', 'smith'): '0.07261164901661495',
#  ('david', 'sterling'): '0.0',
#  ('david', 'strauss'): '0.06573290878638645',
#  ('david', 'todd'): '0.02082912411450186',
#  ('deanne', 'maynard'): '0.0',
#  ('debo', 'adegbile'): '0.0',
#  ('deborah', 'chuang'): '0.0',
#  ('deepak', 'gupta'): '0.0',
#  ('dennis', 'egan'): '0.0',
#  ('dennis', 'riordan'): '0.0',
#  ('dexter', 'lehtinen'): '1.0',
#  ('donald', 'ayer'): '0.0',
#  ('donald', 'donovan'): '0.09613819705639245',
#  ('donald', 'verrilli'): '0.0',
#  ('douglas', 'cole'): '1.0',
#  ('douglas', 'mertz'): '0.0',
#  ('drew', 'days'): '0.0',
#  ('dustin', 'mcdaniel'): '0.0',
#  ('edward', 'dumont'): '0.0',
#  ('edward', 'marshall'): '0.0',
#  ('elaine', 'goldenberg'): '0.0',
#  ('elizabeth', 'jacobs'): '0.0',
#  ('elizabeth', 'kertscher'): '0.0',
#  ('eric', 'albritton'): '0.14556962025316456',
#  ('eric', 'katz'): '0.0',
#  ('eric', 'miller'): '0.0',
#  ('eric', 'multhaup'): '0.0',
#  ('eric', 'zagrans'): '0.0',
#  ('eugene', 'stearns'): '0.0',
#  ('evan', 'tager'): '0.0',
#  ('evan', 'young'): '1.0',
#  ('francis', 'ainsa'): '0.0',
#  ('frank', 'dunham'): '1.0',
#  ('franny', 'forsman'): '0.0',
#  ('frederick', 'schwarz'): '0.0',
#  ('gary', 'feinerman'): '0.0',
#  ('gene', 'schaerr'): '0.9558498896247241',
#  ('geoffrey', 'klineberg'): '0.0',
#  ('george', 'conway'): '1.0',
#  ('george', 'kendall'): '0.0',
#  ('george', 'lemieux'): '1.0',
#  ('george', 'young'): '0.8166666666666667',
#  ('ginger', 'anders'): '0.0',
#  ('glen', 'nager'): '1.0',
#  ('greg', 'abbott'): '1.0',
#  ('gregg', 'levy'): '0.0',
#  ('gregory', 'castanias'): '0.0',
#  ('gregory', 'coleman'): '0.4888888888888889',
#  ('gregory', 'garre'): '1.0',
#  ('gregory', 'katsas'): '1.0',
#  ('harold', 'becker'): '0.0',
#  ('ira', 'sacks'): '0.0',
#  ('irving', 'gornstein'): '0.0',
#  ('jack', 'campbell'): '0.0',
#  ('jacob', 'cohn'): '0.0',
#  ('james', 'backstrom'): '0.3333333333333333',
#  ('james', 'carty'): '0.0',
#  ('james', 'colbert'): '0.0',
#  ('james', 'dabney'): '0.0',
#  ('james', 'deano'): '0.0',
#  ('james', 'feldman'): '0.0',
#  ('james', 'hood'): '0.029940119760479042',
#  ('james', 'hurst'): '0.0',
#  ('james', 'petro'): '1.0',
#  ('james', 'young'): '0.4949186991869919',
#  ('jane', 'webre'): '0.0847457627118644',
#  ('jason', 'hawkins'): '0.0',
#  ('jay', 'jorgensen'): '1.0',
#  ('jay', 'lefkowitz'): '1.0',
#  ('jay', 'sekulow'): '0.9768518518518519',
#  ('jean', 'manning'): '0.0',
#  ('jeffrey', 'bucholtz'): '1.0',
#  ('jeffrey', 'ehrlich'): '0.0',
#  ('jeffrey', 'fisher'): '0.11904761904761904',
#  ('jeffrey', 'keyes'): '0.0',
#  ('jeffrey', 'lamken'): '0.9056603773584906',
#  ('jeffrey', 'sutton'): '0.0',
#  ('jeffrey', 'tilden'): '1.0',
#  ('jeffrey', 'wall'): '0.4473684210526316',
#  ('jennifer', 'smith'): '0.03540179922937689',
#  ('jeremy', 'friedlander'): '0.0',
#  ('jerome', 'muys'): '0.0',
#  ('john', 'arnold'): '1.0',
#  ('john', 'ates'): '0.0',
#  ('john', 'bash'): '1.0',
#  ('john', 'blume'): '0.0',
#  ('john', 'bursch'): '1.0',
#  ('john', 'cline'): '0.5',
#  ('john', 'draper'): '0.0',
#  ('john', 'eastman'): '0.16866374487131666',
#  ('john', 'economidy'): '0.0',
#  ('john', 'elwood'): '0.9199999999999999',
#  ('john', 'gibbons'): '0.3975563909774436',
#  ('john', 'howard'): '0.5145823094171409',
#  ('john', 'iii'): '0.0',
#  ('john', 'jones'): '0.11518225545177777',
#  ('john', 'kester'): '1.0',
#  ('john', 'krill'): '0.9886561954624782',
#  ('john', 'kroger'): '0.0',
#  ('john', 'lewis'): '0.24169246646026832',
#  ('john', 'mcdonald'): '0.320503682584937',
#  ('john', 'mills'): '0.0',
#  ('john', 'neiman'): '1.0',
#  ('john', 'nields'): '0.0',
#  ('john', 'payton'): '0.0',
#  ('john', 'roberts'): '0.26754289597142034',
#  ('john', 'stevens'): '0.28797816531883524',
#  ('john', 'todd'): '0.0',
#  ('john', 'weston'): '0.0',
#  ('jonathan', 'cole'): '0.03568369968598344',
#  ('jonathan', 'libby'): '0.0',
#  ('jonathan', 'marcus'): '0.43993552669005404',
#  ('jonathan', 'mitchell'): '0.0',
#  ('jonathan', 'nuechterlein'): '0.0',
#  ('jonathan', 'willens'): '0.0',
#  ('jordan', 'steiker'): '0.0',
#  ('jose', 'garza'): '0.0',
#  ('joseph', 'guerra'): '0.0',
#  ('joseph', 'jacquot'): '1.0',
#  ('joseph', 'mattingly'): '0.0',
#  ('joseph', 'oneill'): '1.0',
#  ('joseph', 'parkhurst'): '0.0',
#  ('joseph', 'schleimer'): '0.5286233530213539',
#  ('joseph', 'sellers'): '0.0',
#  ('joshua', 'rosenkranz'): '0.0',
#  ('judith', 'resnik'): '0.0',
#  ('julie', 'goldscheid'): '0.0',
#  ('kannon', 'shanmugam'): '1.0',
#  ('karl', 'hays'): '0.0',
#  ('katherine', 'winfree'): '0.0',
#  ('kathleen', 'sullivan'): '0.0',
#  ('kay', 'hodge'): '0.0',
#  ('kenneth', 'mogill'): '0.0',
#  ('kenneth', 'starr'): '1.0',
#  ('kenneth', 'thomas'): '0.851063829787234',
#  ('kent', 'jones'): '1.0',
#  ('kevin', 'culligan'): '0.0',
#  ('kevin', 'newsom'): '1.0',
#  ('kevin', 'russell'): '0.0',
#  ('kimball', 'anderson'): '0.0',
#  ('laura', 'brill'): '0.0',
#  ('laura', 'ferguson'): '0.0',
#  ('laurence', 'tribe'): '0.0',
#  ('lawrence', 'brown'): '0.43643745749829993',
#  ('lawrence', 'robbins'): '0.0',
#  ('leonard', 'simon'): '0.0',
#  ('lewis', 'liman'): '0.0',
#  ('linda', 'thompson'): '0.0',
#  ('lisa', 'blatt'): '0.0',
#  ('lisa', 'madigan'): '0.0',
#  ('lloyd', 'miller'): '0.0',
#  ('malcolm', 'wheeler'): '0.0',
#  ('marc', 'fernich'): '0.8333333333333333',
#  ('maria', 'vullo'): '0.0',
#  ('marilyn', 'burkhardt'): '0.0',
#  ('mark', 'bendure'): '0.0',
#  ('mark', 'bennett'): '0.5232058376276886',
#  ('mark', 'cohen'): '0.2583779621670076',
#  ('mark', 'fleming'): '0.0',
#  ('mark', 'hurt'): '1.0',
#  ('mark', 'johnson'): '0.22993864229373032',
#  ('mark', 'levy'): '0.0',
#  ('mark', 'olson'): '0.0',
#  ('mark', 'perry'): '0.23226773226773229',
#  ('mark', 'rosenbaum'): '0.0',
#  ('mark', 'walters'): '0.0',
#  ('martha', 'coakley'): '0.0',
#  ('mary', 'williams'): '0.0',
#  ('mathew', 'staver'): '1.0',
#  ('matthew', 'nelson'): '1.0',
#  ('matthew', 'roberts'): '0.9',
#  ('matthew', 'shors'): '0.0',
#  ('maureen', 'hart'): '1.0',
#  ('maureen', 'mahoney'): '0.989451476793249',
#  ('meir', 'feder'): '0.0',
#  ('michael', 'cahill'): '1.0',
#  ('michael', 'cardozo'): '0.0',
#  ('michael', 'carvin'): '1.0',
#  ('michael', 'delaney'): '0.0',
#  ('michael', 'fleming'): '0.2582808742897702',
#  ('michael', 'foreman'): '0.0',
#  ('michael', 'fried'): '0.5',
#  ('michael', 'gordon'): '0.1721311475409836',
#  ('michael', 'gottesman'): '0.0',
#  ('michael', 'gross'): '0.0664819944598338',
#  ('michael', 'haglund'): '0.06097560975609756',
#  ('michael', 'hawkins'): '0.5714285714285714',
#  ('michael', 'kellogg'): '1.0',
#  ('michael', 'manely'): '0.0',
#  ('michael', 'mcconnell'): '0.9324324324324325',
#  ('michael', 'mclachlan'): '0.0',
#  ('michael', 'meehan'): '0.9915014164305949',
#  ('michael', 'moore'): '0.09732706075762634',
#  ('michael', 'mukasey'): '0.935483870967742',
#  ('michael', 'rosenbaum'): '0.0',
#  ('michael', 'smith'): '0.3169086541174173',
#  ('michael', 'walton'): '0.0',
#  ('miguel', 'estrada'): '1.0',
#  ('narda', 'pierce'): '0.0',
#  ('nathan', 'lewin'): '1.0',
#  ('nicholas', 'rosenkranz'): '1.0',
#  ('pamela', 'karlan'): '0.0',
#  ('patricia', 'millett'): '0.0',
#  ('patrick', 'coughlin'): '0.004',
#  ('paul', 'bender'): '1.0',
#  ('paul', 'boas'): '0.25',
#  ('paul', 'hoffman'): '0.39601850516956444',
#  ('paul', 'rashkind'): '0.0',
#  ('paul', 'roadarmel'): '1.0',
#  ('paul', 'salvatore'): '0.0',
#  ('paul', 'smith'): '0.08950545727963642',
#  ('paul', 'stern'): '0.0',
#  ('paul', 'strandness'): '0.0',
#  ('paul', 'wolfson'): '0.0',
#  ('peter', 'brann'): '0.0',
#  ('peter', 'eliasberg'): '0.0',
#  ('peter', 'gold'): '0.6666666666666666',
#  ('peter', 'keisler'): '1.0',
#  ('peter', 'rubin'): '0.0',
#  ('peter', 'stirba'): '1.0',
#  ('quin', 'denvir'): '0.0',
#  ('r', 'pate'): '0.0',
#  ('r', 'phillips'): '0.0',
#  ('ralph', 'meczyk'): '0.0',
#  ('randall', 'allen'): '0.0',
#  ('randall', 'roske'): '0.0',
#  ('rebecca', 'harper'): '0.0',
#  ('reuben', 'cahn'): '0.0',
#  ('richard', 'bernstein'): '0.0662940654052643',
#  ('richard', 'blumenthal'): '0.0',
#  ('richard', 'bress'): '0.0',
#  ('richard', 'cooper'): '0.0',
#  ('richard', 'cordray'): '0.0',
#  ('richard', 'diaz'): '0.0',
#  ('richard', 'faulk'): '0.8583333333333334',
#  ('richard', 'friedman'): '0.41485001407712074',
#  ('richard', 'hogan'): '0.0',
#  ('richard', 'kendall'): '0.0',
#  ('richard', 'mescon'): '0.0',
#  ('richard', 'salzman'): '0.0',
#  ('robert', 'bartels'): '0.0',
#  ('robert', 'brownlee'): '0.0',
#  ('robert', 'dolan'): '0.0',
#  ('robert', 'fishman'): '0.0',
#  ('robert', 'foster'): '0.853299856527977',
#  ('robert', 'friedman'): '0.03986826139712255',
#  ('robert', 'harris'): '0.01737228245385574',
#  ('robert', 'klausner'): '0.0054466230936819175',
#  ('robert', 'long'): '0.3638457203316736',
#  ('robert', 'owen'): '0.9985696771557009',
#  ('robert', 'peck'): '0.0',
#  ('robert', 'swift'): '0.016722408026755852',
#  ('robert', 'yablon'): '0.0',
#  ('roberta', 'kaplan'): '0.0',
#  ('roberto', 'lange'): '0.0',
#  ('robinson', 'everett'): '0.3333333333333333',
#  ('roger', 'greenberg'): '0.21524064171122995',
#  ('ronald', 'molteni'): '0.0',
#  ('ronald', 'nessim'): '1.0',
#  ('ronnie', 'mitchell'): '0.0',
#  ('roy', 'davis'): '0.0',
#  ('roy', 'englert'): '1.0',
#  ('samuel', 'buffone'): '0.0',
#  ('sarah', 'harrington'): '0.0',
#  ('scott', 'hunt'): '0.0',
#  ('scott', 'makar'): '1.0',
#  ('scott', 'nelson'): '0.3858168631654727',
#  ('sean', 'gallagher'): '0.1875',
#  ('sean', 'jordan'): '1.0',
#  ('sean', 'kennedy'): '0.0',
#  ('seth', 'galanter'): '0.0',
#  ('seth', 'waxman'): '0.0',
#  ('sharon', 'samek'): '0.0',
#  ('sheldon', 'richie'): '1.0',
#  ('steffen', 'johnson'): '1.0',
#  ('stephanos', 'bibas'): '1.0',
#  ('stephen', 'bedrick'): '0.0',
#  ('stephen', 'bruce'): '0.0',
#  ('stephen', 'fitch'): '1.0',
#  ('stephen', 'gordon'): '0.018518518518518517',
#  ('stephen', 'kinnaird'): '0.0',
#  ('stephen', 'kissinger'): '0.0',
#  ('stephen', 'sanders'): '0.6',
#  ('stephen', 'shapiro'): '0.8685759145912924',
#  ('steven', 'gordon'): '0.0',
#  ('steven', 'hubachek'): '0.0',
#  ('steven', 'reiss'): '0.0',
#  ('steven', 'rosenthal'): '0.5591230662924629',
#  ('steven', 'shapiro'): '0.0',
#  ('steven', 'sherman'): '0.16366612111292964',
#  ('steven', 'wax'): '0.0',
#  ('steven', 'wells'): '0.0',
#  ('stuart', 'somach'): '0.5714285714285714',
#  ('susan', 'freeman'): '0.0',
#  ('susan', 'smith'): '-0.0032147828574918907',
#  ('susan', 'ullman'): '0.0',
#  ('t', 'kelly'): '1.0',
#  ('tara', 'allen'): '0.0',
#  ('theodore', 'allison'): '0.0',
#  ('theodore', 'boutrous'): '0.002472799208704253',
#  ('theodore', 'olson'): '0.9901960784313726',
#  ('thomas', 'barnett'): '0.7529680365296804',
#  ('thomas', 'byrne'): '0.0',
#  ('thomas', 'casey'): '0.4304347826086956',
#  ('thomas', 'davidson'): '1.0',
#  ('thomas', 'dubbs'): '0.051490514905149054',
#  ('thomas', 'fisher'): '0.05963228348710511',
#  ('thomas', 'goldstein'): '0.0',
#  ('thomas', 'hefferon'): '0.0',
#  ('thomas', 'horne'): '1.0',
#  ('thomas', 'hungar'): '1.0',
#  ('thomas', 'michel'): '0.9090909090909091',
#  ('thomas', 'miller'): '0.34014806386840046',
#  ('thomas', 'peters'): '0.45454545454545453',
#  ('thomas', 'shipps'): '0.0',
#  ('thomas', 'whalen'): '0.0',
#  ('timothy', 'bishop'): '1.0',
#  ('timothy', 'kelly'): '0.6511110582155988',
#  ('toby', 'heytens'): '0.0',
#  ('todd', 'marshall'): '0.5555555555555556',
#  ('todd', 'schneider'): '0.06119523026890933',
#  ('traci', 'lovitt'): '1.0',
#  ('troy', 'giatras'): '0.0',
#  ('verna', 'williams'): '0.0',
#  ('vicki', 'jackson'): '0.0',
#  ('victor', 'haltom'): '0.0',
#  ('virginia', 'seitz'): '0.0',
#  ('w', 'plowden'): '1.0',
#  ('walter', 'dellinger'): '0.0',
#  ('warren', 'wolf'): '0.0',
#  ('william', 'boyce'): '1.0',
#  ('william', 'brown'): '0.21055693545331977',
#  ('william', 'collins'): '0.20978831347592225',
#  ('william', 'coston'): '0.0',
#  ('william', 'jay'): '1.0',
#  ('william', 'kayatta'): '0.0',
#  ('william', 'mallin'): '1.0',
#  ('william', 'reynolds'): '0.7924477861944679',
#  ('william', 'smiland'): '1.0',
#  ('william', 'sullivan'): '0.8189551750463518',
#  ('william', 'young'): '0.7746112594346588',
#  ('willis', 'goldsmith'): '0.6976981351981353'}

# %% [markdown]
# **Finally, we generate the dataset**: one file per vowel in a word (charged or uncharged), and each file contains a list of
# ideology, phonetics_data
# where phonetics_data is
# 'count','formant1','formant2','duration','F11','F12','F13','F21','F22','F23'

# %%
for entry in vowels_final:
    ideology,word,vowel,position = entry
    if word in non_charged:
        thisword = open("gathered_data/non_charged/"+str(word)+'_'+str(vowel)+'_'+str(position)+'.txt', 'a')
        thisword.write(str(ideology)+','+str(vowels_final[entry]).replace('[', '').replace(']','')+'\n')
        thisword.close()
    elif word in charged:
        thisword = open("gathered_data/charged/"+str(word)+'_'+str(vowel)+'_'+str(position)+'.txt', 'a')
        thisword.write(str(ideology)+','+str(vowels_final[entry]).replace('[', '').replace(']','')+'\n')
        thisword.close()
    else:
        pass
