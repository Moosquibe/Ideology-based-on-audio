# %% [markdown]
# # Connecting speakers, ideology and phonetics
#
# We form our working phonetics-based dataset.

# %%
formants=open("gathered_data/wordssyllablesformants.txt",'r')
list_formants=formants.readlines()

# %% [markdown]
# - **Data cleaning.** First, we reformat the data produced by the gathering scripts.
# We form a dictionary whose keys are tuples (speaker, word, vowel, position_in_the_word) and values are the phonetics data, namely a list $[\text{frequence 1}, \text{frequence 2}, \text{duration}, \text{formant1}, \text{formant 2}]$ where both formant1 and formant2 are themselves lists containing 3 frequences.
# The script also populates a list of all the speakers.

# %%
def reformat(l,vowels_dict,names_list):
    l=l.replace('[','')
    l=l.replace(']','')
    l=l.replace("'",'')
    l=l.replace(' ','')
    l=l.split(',')
    word=l[0]
    speaker=l[1].lower()
    for i in range(3,len(l),13):
        position = ((i-3)/13)+1
        sublist=l[i:i+12]
        vowel=sublist[0]
        freq1=float(sublist[1])
        freq2=float(sublist[2])
        duration=float(sublist[3])
        formant1=[float(i) for i in sublist[4:7]]
        formant2=[float(i) for i in sublist[8:11]]
        if (speaker,word,vowel,position) in vowels_dict:
            v=vowels_dict[(speaker,word,vowel,position)]
            v[0]+=1
            v[1]+=freq1
            v[2]+=freq2
            v[3]+=duration
            for i in range(len(formant1)):
                v[4][i]+=formant1[i]
                v[5][i]+=formant2[i]

        else:
            vowels_dict[(speaker,word,vowel,position)]=[1,freq1,freq2,duration,formant1,formant2]    
    names_list.append(speaker)
    
vowels_dict={}
names_list=[]
for line in list_formants:
    reformat(line,vowels_dict,names_list)

names_list=list(set(names_list)) #in order to remove duplicates
len(names_list)
# Out:
# 804

# %% [markdown]
# - **Averaging the formants.** This is an important step.
# We average the phonetics data for each key of our dictionary. This in order the future data analysis to overestimate the role of certain "dominant" speakers in the ideology prediction. As a result, we still have a dictionary whose keys are (speaker, word, vowel), but the value is now a single, averaged phonetics information.

# %%
for e in vowels_dict:
    v=vowels_dict[e]
    count=v[0]
    v[1]=v[1]/count
    v[2]=v[2]/count
    v[3]=v[3]/count
    formant1=v[4]
    for i in range(len(formant1)):
        v[4][i]=v[4][i]/count
        v[5][i]=v[5][i]/count

# %% [markdown]
# - **Getting the ideology for each speaker.**
# However, not all the speakers appear in ideodefined.txt as the donations record for some speakers either weren't found or don't allow to conclude regarding their political orientation.
# We form a dictionary where keys are (first, last name) and values are the ideology. We find 433 different speakers with ideology.

# %%
ideology=open("gathered_data/ideodefined.txt",'r')  #file containing speakers and their respective ideology. 
list_ideology=ideology.readlines()
ideology_dict={}
names=[]
for e in list_ideology:
    l=e[:-1].split(',')
    first_name=l[0]
    last_name=l[1]
    ideo=l[2]
    ideology_dict[(first_name,last_name)]=ideo
    names.append((first_name,last_name))

# %% [markdown]
# We also create a dictionary to match names (as they do not have the same format in both files)

# %%
wordsyllablesformant_names=list(set(names_list[:]))
ideology_names=list(set(names[:]))
match={}
for m in ideology_names:
    for n in wordsyllablesformant_names:
        if (m[0] in n and m[1].replace("'",'') in n):  #replace the ' by a blank for Irish names
            wordsyllablesformant_names.remove(n)
            match[n]=m

# %% [markdown]
# - **Replacing names by ideology in the phonetics dataset**

# %%
vowels_ideology={}
keys=[]
for e in vowels_dict:
    keys.append(e)
for k in keys:
    speaker=k[0]
    word=k[1]
    vowel=k[2]
    position=k[3]
    v=vowels_dict[k]
    try:
        sep_name=match[speaker]
        ideology_of_speaker=ideology_dict[sep_name]
        vowels_ideology[(speaker,ideology_of_speaker,word,vowel,position)]=v
    except KeyError:
        oops=1

# %% [markdown]
# We do some more data formatting so that the values in the dictionary are as follows

# %%
col=['count','formant1','formant2','duration','F11','F12','F13','F21','F22','F23']

# %%
vowels_final={}
for e in vowels_ideology:
    l=[]
    v=vowels_ideology[e]
    l=v[0:4]
    for i in v[4]:
        l.append(i)
    for j in v[5]:
        l.append(j)
    vowels_final[e]=l

# %% [markdown]
# - ** Most used words ** We list the words by decreasing frequency, we select the top 20 words (that do not seem to be ideologically relevant) and we arbitrarily pick the first 20 words that may have some ideological content.

# %%
count={}
for e in vowels_final:
    try:
        count[e[1]]+=1
    except KeyError:
        count[e[1]]=1

import operator
sorted_count = sorted(count.items(), key=operator.itemgetter(1),)
sorted(count.items(), key=lambda x: -x[1])
# Out:
# [('0.0', 351019),
#  ('1.0', 119021),
#  ('0.26754289597142034', 27276),
#  ('0.28797816531883524', 15416),
#  ('0.9901960784313726', 9744),
#  ('0.11904761904761904', 7987),
#  ('0.9056603773584906', 4714),
#  ('0.989451476793249', 4582),
#  ('0.9', 4579),
#  ('0.3638457203316736', 3866),
#  ('0.4888888888888889', 3528),
#  ('0.8685759145912924', 3505),
#  ('0.4473684210526316', 3421),
#  ('0.08950545727963642', 3200),
#  ('0.5', 2949),
#  ('0.047573739295908656', 2814),
#  ('0.037286724927174365', 2724),
#  ('0.9199999999999999', 2638),
#  ('0.39601850516956444', 2593),
#  ('0.4304347826086956', 2546),
#  ('0.9768518518518519', 2354),
#  ('0.9985696771557009', 2274),
#  ('0.9324324324324325', 2205),
#  ('0.23226773226773229', 2132),
#  ('0.002472799208704253', 2081),
#  ('0.03540179922937689', 2059),
#  ('0.20978831347592225', 1982),
#  ('0.4949186991869919', 1952),
#  ('0.3858168631654727', 1945),
#  ('0.7004124065641378', 1842),
#  ('0.3333333333333333', 1811),
#  ('0.43993552669005404', 1800),
#  ('0.3975563909774436', 1691),
#  ('0.5714285714285714', 1498),
#  ('0.7252567693744165', 1492),
#  ('0.9558498896247241', 1461),
#  ('0.5232058376276886', 1458),
#  ('0.044642857142857144', 1416),
#  ('0.07261164901661495', 1401),
#  ('0.8333333333333333', 1340),
#  ('0.06097560975609756', 1332),
#  ('0.0847457627118644', 1285),
#  ('0.051490514905149054', 1281),
#  ('0.5591230662924629', 1260),
#  ('0.875', 1254),
#  ('0.09732706075762634', 1235),
#  ('0.25', 1223),
#  ('0.09613819705639245', 1221),
#  ('0.06573290878638645', 1214),
#  ('0.007246376811594203', 1209),
#  ('0.22993864229373032', 1164),
#  ('0.5286233530213539', 1156),
#  ('0.01825117263784198', 1149),
#  ('0.08250825082508251', 1149),
#  ('0.0664819944598338', 1129),
#  ('0.853299856527977', 1119),
#  ('0.30319148936170215', 1103),
#  ('0.14556962025316456', 1101),
#  ('0.1721311475409836', 1095),
#  ('0.0054466230936819175', 1091),
#  ('0.01737228245385574', 1090),
#  ('0.0662940654052643', 1085),
#  ('0.4857142857142857', 1081),
#  ('0.41485001407712074', 1043),
#  ('0.8583333333333334', 1023),
#  ('0.20833333333333334', 1022),
#  ('0.4699356283782079', 1001),
#  ('0.7746112594346588', 1000),
#  ('0.6976981351981353', 1000),
#  ('0.11457431215500621', 987),
#  ('0.4827586206896552', 983),
#  ('0.9090909090909091', 983),
#  ('0.03568369968598344', 976),
#  ('0.3169086541174173', 975),
#  ('0.43643745749829993', 974),
#  ('0.6047008547008548', 968),
#  ('0.6511110582155988', 963),
#  ('0.8914565826330532', 956),
#  ('0.016722408026755852', 952),
#  ('0.9915014164305949', 951),
#  ('0.09401709401709402', 945),
#  ('0.5555555555555556', 928),
#  ('0.004', 919),
#  ('0.003323262839879154', 915),
#  ('0.45454545454545453', 897),
#  ('0.018518518518518517', 883),
#  ('0.16866374487131666', 858),
#  ('0.6', 856),
#  ('0.5145823094171409', 845),
#  ('0.03986826139712255', 838),
#  ('0.16366612111292964', 834),
#  ('0.7924477861944679', 818),
#  ('0.8189551750463518', 813),
#  ('0.6666666666666666', 808),
#  ('0.21524064171122995', 803),
#  ('0.029940119760479042', 798),
#  ('0.2583779621670076', 767),
#  ('0.05963228348710511', 760),
#  ('0.0461236316271587', 736),
#  ('0.11518225545177777', 724),
#  ('0.9886561954624782', 709),
#  ('0.935483870967742', 709),
#  ('0.06119523026890933', 705),
#  ('-0.0032147828574918907', 699),
#  ('0.3468338725085468', 691),
#  ('0.8166666666666667', 669),
#  ('0.320503682584937', 663),
#  ('0.2582808742897702', 652),
#  ('0.1875', 651),
#  ('0.16129032258064516', 650),
#  ('0.851063829787234', 647),
#  ('0.34014806386840046', 611),
#  ('0.02082912411450186', 595),
#  ('0.21055693545331977', 579),
#  ('0.24169246646026832', 536),
#  ('0.7529680365296804', 455),
#  ('0.6153846153846154', 49)]

# %%
non_charged=['SITUATION','BECAUSE','EXAMPLE','PARTICULAR','DIFFERENT','CERTAINLY',
             'IMPORTANT','INTO','ABSOLUTELY','ABOUT','UNDER','SPECIFICALLY','WHETHER',
            'OTHER','EXACTLY']
charged=['FEDERAL','SCALIA','OPPORTUNITY','STATUTORY','HONOR','MR','LEGISLATIVE',
         'CONSTITUTIONAL','KENNEDY','AUTHORITY','GINSBURG','LEGISLATURE','PEOPLE',
        'POLICY','CONGRESS','GOVERNMENT','AMENDMENT','CONSTITUTION','ECONOMIC',
         'CALIFORNIA']

# %% [markdown]
# **Finally, we generate the dataset**: one file per vowel in a word (charged or uncharged), and each file contains a list of
# ideology, phonetics_data
# where phonetics_data is
# 'count','formant1','formant2','duration','F11','F12','F13','F21','F22','F23'

# %%
for entry in vowels_final:
    ideology,word,vowel,position = entry
    if word in non_charged:
        thisword = open("gathered_data/non_charged/"+str(word)+'_'+str(vowel)+'_'+str(position)+'.txt', 'a')
        thisword.write(str(ideology)+','+str(vowels_final[entry]).replace('[', '').replace(']','')+'\n')
        thisword.close()
    elif word in charged:
        thisword = open("gathered_data/charged/"+str(word)+'_'+str(vowel)+'_'+str(position)+'.txt', 'a')
        thisword.write(str(ideology)+','+str(vowels_final[entry]).replace('[', '').replace(']','')+'\n')
        thisword.close()
    else:
        pass

# %% [markdown]
# Count the number of different speakers per word

# %%
word_speakers = {}
word_count = {}
for word in charged:
    word_speakers[word] = {}
for word in non_charged:
    word_speakers[word] = {}
    
for entry in vowels_final:
    speaker,ideology,word,vowel,position = entry
    if (word in non_charged) or (word in charged):      
        c = word_speakers[word].get(speaker, 0)
        word_speakers[word][speaker] = c + 1

for word in word_speakers:
    word_count[word] = len(word_speakers[word])

# %%
word_count
# Out:
# {'ABOUT': 433,
#  'ABSOLUTELY': 216,
#  'AMENDMENT': 200,
#  'AUTHORITY': 195,
#  'BECAUSE': 456,
#  'CALIFORNIA': 95,
#  'CERTAINLY': 337,
#  'CONGRESS': 282,
#  'CONSTITUTION': 119,
#  'CONSTITUTIONAL': 199,
#  'DIFFERENT': 393,
#  'ECONOMIC': 66,
#  'EXACTLY': 277,
#  'EXAMPLE': 303,
#  'FEDERAL': 309,
#  'GINSBURG': 258,
#  'GOVERNMENT': 256,
#  'HONOR': 364,
#  'IMPORTANT': 314,
#  'INTO': 383,
#  'KENNEDY': 199,
#  'LEGISLATIVE': 151,
#  'LEGISLATURE': 85,
#  'MR': 434,
#  'OPPORTUNITY': 152,
#  'OTHER': 435,
#  'PARTICULAR': 301,
#  'PEOPLE': 250,
#  'POLICY': 176,
#  'SCALIA': 269,
#  'SITUATION': 294,
#  'SPECIFICALLY': 235,
#  'STATUTORY': 204,
#  'UNDER': 436,
#  'WHETHER': 421}

# %%
word_speakers['MR']
# Out:
# {'aaronmpanner': 2,
#  'alanbmorrison': 2,
#  'alanedwarduntereiner': 2,
#  'alangura': 2,
#  'alanmfreedman': 2,
#  'alexanderfreichert': 2,
#  'allisonmzieve': 2,
#  'amandacleiter': 2,
#  'amyhowe': 2,
#  'amyzapp': 2,
#  'andrewjpincus': 2,
#  'andrewjrossman': 2,
#  'andrewlfrey': 2,
#  'anitaalvarez': 2,
#  'annoconnell': 2,
#  'anthonyayang': 2,
#  'anthonyyang': 2,
#  'arthurffergenson': 2,
#  'arthurhbryant': 2,
#  'barbarabmcdowell': 2,
#  'barrybarnett': 2,
#  'barryrostrager': 2,
#  'beaubbrindley': 2,
#  'berthdeixler': 2,
#  'bethsbrinkmann': 2,
#  'bradleysphillips': 2,
#  'brianfbarov': 2,
#  'brianplauten': 2,
#  'brianshiffrin': 2,
#  'brianwolfman': 2,
#  'brucecsmith': 2,
#  'brucejennisjr': 2,
#  'brucejterris': 2,
#  'caitlinjhalligan': 2,
#  'candacecain': 2,
#  'carolynakubitschek': 2,
#  'cartergphillips': 2,
#  'catherineestetson': 4,
#  'catherinewsmith': 2,
#  'cchristophertrower': 2,
#  'chadareadler': 4,
#  'charlesalanwright': 2,
#  'charlesarothfeld': 2,
#  'charlescondon': 2,
#  'charlesjcooper': 2,
#  'charlesmsevilla': 2,
#  'charlesssims': 2,
#  'christophergbrowningjr': 2,
#  'christopherjmeade': 2,
#  'christopherjpaolella': 2,
#  'christopherlandau': 2,
#  'christopherpburke': 2,
#  'clayriggssmith': 2,
#  'cliffordmsloan': 2,
#  'cliftonthutchinson': 2,
#  'collynpeddie': 2,
#  'conniellensing': 2,
#  'corbettgordon': 2,
#  'corinneabeckwith': 2,
#  'courtlandlreichman': 2,
#  'craigggoldblatt': 2,
#  'craigtjones': 2,
#  'curtisegannon': 2,
#  'danbjohnson': 2,
#  'danielasmall': 2,
#  'danielhbromberg': 2,
#  'daniellespinelli': 2,
#  'danielrortiz': 2,
#  'daryljoseffer': 2,
#  'davidafurlow': 2,
#  'davidalane': 2,
#  'davidamoran': 4,
#  'davidastrauss': 2,
#  'davidboies': 2,
#  'davidbsalmons': 2,
#  'davidcfrederick': 2,
#  'davidctodd': 2,
#  'daviddlawrence': 2,
#  'davidemills': 2,
#  'davidjburman': 2,
#  'davidjeremybederman': 2,
#  'davidlew': 2,
#  'davidlrose': 2,
#  'davidmneff': 2,
#  'davidmporter': 2,
#  'davidmsmith': 2,
#  'davidoneil': 2,
#  'davidsterling': 2,
#  'davidwbowker': 2,
#  'davidwrobbins': 2,
#  'deanneemaynard': 2,
#  'debopadegbile': 2,
#  'deborahjanechuang': 2,
#  'deepakgupta': 2,
#  'denniseegan': 2,
#  'dennispriordan': 2,
#  'dexterwlehtinen': 2,
#  'donaldbayer': 2,
#  'donaldbverrilli': 2,
#  'donaldbverrillijr': 2,
#  'donaldfrancisdonovan': 2,
#  'douglaskmertz': 2,
#  'douglasrcole': 2,
#  'drewsdaysiii': 2,
#  'dustinmcdaniel': 2,
#  'edwardcdumont': 2,
#  'edwardlmarshall': 2,
#  'ejoshuarosenkranz': 2,
#  'elainejgoldenberg': 2,
#  'elizabethljacobs': 2,
#  'elizabethskertscher': 2,
#  'ericdkatz': 2,
#  'ericdmiller': 2,
#  'erichzagrans': 2,
#  'ericmalbritton': 2,
#  'ericsmulthaup': 2,
#  'eugeneestearns': 2,
#  'evanayoung': 2,
#  'evanmarktager': 2,
#  'francissainsajr': 2,
#  'frankwdunhamjr': 2,
#  'frannyaforsman': 2,
#  'frederickaoschwarzjr': 2,
#  'garyfeinerman': 2,
#  'garysfeinerman': 2,
#  'genecschaerr': 2,
#  'gensethpwaxman': 2,
#  'gentheodorebolson': 2,
#  'geoffreymklineberg': 2,
#  'georgehkendall': 2,
#  'georgeparkeryoung': 2,
#  'georgeslemieux': 2,
#  'georgetconwayiii': 2,
#  'gingeranders': 2,
#  'gingerdanders': 2,
#  'glendnager': 2,
#  'gregabbott': 2,
#  'gregghlevy': 2,
#  'gregoryacastanias': 2,
#  'gregoryandrewcastanias': 2,
#  'gregoryggarre': 5,
#  'gregorygkatsas': 2,
#  'gregoryscoleman': 2,
#  'haroldcbecker': 2,
#  'irvinglgornstein': 2,
#  'jackwilliamcampbelliv': 2,
#  'jacobccohn': 2,
#  'jamesafeldman': 2,
#  'jamescbackstrom': 2,
#  'jamesfhurst': 2,
#  'jamesldeano': 2,
#  'jamesmpetro': 2,
#  'jamesrcarty': 2,
#  'jamesryoung': 2,
#  'jameswcolbertiii': 2,
#  'jameswdabney': 2,
#  'janewebre': 2,
#  'jasondhawkins': 4,
#  'jayasekulow': 2,
#  'jayplefkowitz': 2,
#  'jaysekulow': 2,
#  'jaytjorgensen': 2,
#  'jeanmmanning': 2,
#  'jeffreyalamken': 2,
#  'jeffreybwall': 2,
#  'jeffreyfisher': 2,
#  'jeffreyitilden': 2,
#  'jeffreyjkeyes': 2,
#  'jeffreylehrlich': 2,
#  'jeffreylfisher': 2,
#  'jeffreysbucholtz': 2,
#  'jeffreyssutton': 2,
#  'jenniferlsmith': 2,
#  'jeremyfriedlander': 2,
#  'jeromecmuys': 2,
#  'johnapayton': 2,
#  'johnbdraper': 2,
#  'johnbhowardjr': 2,
#  'johnceastman': 2,
#  'johncjones': 2,
#  'johncneimanjr': 2,
#  'johndcline': 2,
#  'johnfbash': 2,
#  'johngeorgeknorriii': 2,
#  'johngkester': 2,
#  'johngroberts': 4,
#  'johngrobertsjr': 6,
#  'johnhblume': 2,
#  'johnhweston': 2,
#  'johnjarnold': 2,
#  'johnjbursch': 2,
#  'johnjgibbons': 2,
#  'johnknodelliii': 2,
#  'johnmeconomidy': 2,
#  'johnpaulstevens': 4,
#  'johnpelwood': 2,
#  'johnpkrilljr': 2,
#  'johnpmcdonald': 3,
#  'johnptodd': 2,
#  'johnrates': 2,
#  'johnrkroger': 2,
#  'johnsmills': 2,
#  'johnwnieldsjr': 2,
#  'jonathananuechterlein': 2,
#  'jonathanawillens': 2,
#  'jonathanbcole': 2,
#  'jonathandlibby': 2,
#  'jonathanfmitchell': 2,
#  'jonathanlmarcus': 2,
#  'jordansteiker': 2,
#  'josegarza': 2,
#  'josephdoneill': 4,
#  'josephdschleimer': 2,
#  'josephhmattinglyiii': 2,
#  'josephlparkhurst': 2,
#  'josephmsellers': 2,
#  'josephrguerra': 2,
#  'josephwjacquot': 2,
#  'joshuaerosenkranz': 2,
#  'judithresnik': 2,
#  'juliegoldscheid': 4,
#  'kannonkshanmugam': 2,
#  'karlehays': 2,
#  'katherinewinfree': 2,
#  'kathleenmsullivan': 2,
#  'kayhhodge': 2,
#  'kennethlthomas': 2,
#  'kennethmmogill': 2,
#  'kennethwstarr': 2,
#  'kentljones': 2,
#  'kevincnewsom': 2,
#  'kevinjculligan': 2,
#  'kevinkrussell': 2,
#  'kimballranderson': 2,
#  'lauragferguson': 2,
#  'laurawbrill': 2,
#  'lawrencecbrown': 2,
#  'lawrencesrobbins': 2,
#  'leonardbsimon': 2,
#  'lewisliman': 2,
#  'lindajthompson': 2,
#  'lisablatt': 2,
#  'lisamadigan': 2,
#  'lisasblatt': 2,
#  'lisaschiavoblatt': 2,
#  'mariatvullo': 2,
#  'marilyngburkhardt': 2,
#  'markajohnson': 2,
#  'markaperry': 2,
#  'markcfleming': 2,
#  'markdolson': 2,
#  'markdrosenbaum': 2,
#  'markhcohen': 2,
#  'markilevy': 2,
#  'markpwalters': 2,
#  'markrbendure': 2,
#  'markthurt': 2,
#  'maryhwilliams': 2,
#  'matthewdroberts': 2,
#  'matthewmshors': 2,
#  'matthewtnelson': 2,
#  'maureenahart': 2,
#  'maureenemahoney': 2,
#  'meirfeder': 2,
#  'michaelacardozo': 2,
#  'michaelacarvin': 2,
#  'michaeladelaney': 2,
#  'michaelbmukasey': 2,
#  'michaelcwalton': 2,
#  'michaelehaglund': 2,
#  'michaelemanely': 2,
#  'michaelemclachlan': 2,
#  'michaelemoore': 2,
#  'michaelgordon': 2,
#  'michaelgottesman': 2,
#  'michaelhgottesman': 2,
#  'michaeljcahill': 2,
#  'michaeljmeehan': 2,
#  'michaelkellogg': 2,
#  'michaelkkellogg': 2,
#  'michaellforeman': 2,
#  'michaelmrosenbaum': 2,
#  'michaelpfleming': 2,
#  'michaelsfried': 2,
#  'michaelwgross': 2,
#  'michaelwhawkins': 2,
#  'michaelwmcconnell': 2,
#  'miguelaestrada': 2,
#  'miguelestrada': 2,
#  'nardapierce': 2,
#  'nathanlewin': 2,
#  'nicholasqrosenkranz': 2,
#  'pamelaskarlan': 2,
#  'patriciaamillett': 2,
#  'patrickjcoughlin': 2,
#  'paulastrandness': 2,
#  'paulbender': 2,
#  'paulhoffman': 2,
#  'paullhoffman': 2,
#  'paulmrashkind': 2,
#  'paulmroadarmeljr': 2,
#  'paulmsmith': 2,
#  'paulrqwolfson': 2,
#  'paulsalvatore': 2,
#  'paulstern': 2,
#  'peterdkeisler': 2,
#  'petergold': 2,
#  'peterjbrann': 2,
#  'peterjeliasberg': 2,
#  'peterjrubin': 2,
#  'peterstirba': 2,
#  'petitionerpatriciaamillett': 2,
#  'petitionerscottdmakar': 2,
#  'quindenvir': 2,
#  'ralphemeczyk': 2,
#  'randalljroske': 2,
#  'randalllallen': 2,
#  'rebeccajharper': 2,
#  'reubenccahn': 2,
#  'rhewittpate': 2,
#  'richardamescon': 2,
#  'richardasalzman': 2,
#  'richardblumenthal': 2,
#  'richardcordray': 2,
#  'richarddbernstein': 2,
#  'richarddfriedman': 2,
#  'richardjdiaz': 2,
#  'richardmcooper': 2,
#  'richardofaulk': 2,
#  'richardpbress': 2,
#  'richardphoganjr': 2,
#  'robertaakaplan': 2,
#  'robertalongjr': 2,
#  'robertaswift': 2,
#  'robertcowen': 2,
#  'robertdbartels': 2,
#  'robertdklausner': 2,
#  'robertedolan': 2,
#  'robertffriedman': 2,
#  'roberthbrownlee': 2,
#  'robertmfoster': 2,
#  'robertmyablon': 2,
#  'robertoalange': 2,
#  'robertqharris': 2,
#  'robertspeck': 2,
#  'roberttfishman': 2,
#  'robinsonoeverett': 2,
#  'rogerbgreenberg': 2,
#  'ronaldjnessim': 2,
#  'ronaldmolteni': 2,
#  'ronniemmitchell': 2,
#  'roygdavis': 2,
#  'roytenglert': 2,
#  'roytenglertjr': 2,
#  'rstuartphillips': 2,
#  'samueljbuffone': 2,
#  'saraheharrington': 2,
#  'scottdmakar': 2,
#  'scottlnelson': 2,
#  'scottnhunt': 2,
#  'seandjordan': 2,
#  'seankkennedy': 2,
#  'seanrgallagher': 2,
#  'sethmgalanter': 2,
#  'sethpwaxman': 2,
#  'sharoncsamek': 2,
#  'sheldonerichie': 2,
#  'steffennjohnson': 2,
#  'stephanosbibas': 2,
#  'stephenbbedrick': 2,
#  'stephenbkinnaird': 2,
#  'stephencfitch': 2,
#  'stephencgordon': 2,
#  'stephenmkissinger': 2,
#  'stephenmshapiro': 2,
#  'stephenrbruce': 2,
#  'stephensanders': 2,
#  'stevenalanreiss': 2,
#  'stevencsherman': 2,
#  'stevendgordon': 2,
#  'stevenfhubachek': 2,
#  'stevenjwells': 2,
#  'stevenrshapiro': 2,
#  'stevensrosenthal': 2,
#  'steventwax': 2,
#  'susanksmith': 2,
#  'susankullman': 2,
#  'susanmfreeman': 2,
#  'tarakallen': 2,
#  'tchristopherkelly': 2,
#  'theodorebolson': 2,
#  'theodorejboutrousjr': 2,
#  'theodoresallison': 2,
#  'thomasadubbs': 2,
#  'thomascgoldstein': 2,
#  'thomaschorne': 2,
#  'thomasghungar': 2,
#  'thomashshipps': 2,
#  'thomasjdavidson': 2,
#  'thomasjmiller': 2,
#  'thomasjwhalen': 2,
#  'thomaslcasey': 2,
#  'thomasmbyrne': 2,
#  'thomasmfisher': 2,
#  'thomasmhefferon': 2,
#  'thomasmmichel': 2,
#  'thomasobarnett': 2,
#  'thomaspeters': 2,
#  'timothymkelly': 2,
#  'timothysbishop': 2,
#  'tobyjheytens': 2,
#  'toddmarshall': 2,
#  'toddmschneider': 2,
#  'troyngiatras': 2,
#  'vernalwilliams': 2,
#  'vickicjackson': 2,
#  'victorshaltom': 2,
#  'virginiaaseitz': 2,
#  'walterdellinger': 2,
#  'walteredellinger': 2,
#  'warrenawolf': 2,
#  'williambcollins': 2,
#  'williambmallin': 2,
#  'williambradfordreynolds': 2,
#  'williamdcoston': 2,
#  'williamjboyce': 2,
#  'williamjbrown': 2,
#  'williamjkayattajr': 2,
#  'williamjyoung': 2,
#  'williammjay': 2,
#  'willisjgoldsmith': 2,
#  'wjamesyoung': 2,
#  'wmrobertlongjr': 2,
#  'wwarrenplowdenjr': 2}
